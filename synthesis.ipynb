# %%
from z3 import *

import yaml
import pandas as pd

from dataclasses import dataclass
from pprint import pprint
from typing import Optional
from itertools import product

pd.set_option('display.max_rows', None)

# %%
MM_FILE = './assets/metamodels/doml_meta_v2.0.yaml'

# IM_FILE = './assets/doml/2.0/nginx-openstack_v2.0.yaml'
IM_FILE = './assets/doml/2.0/nginx-openstack_v2.0_wrong_vm_iface.yaml'

UB_ELEMS = 0

# %%
with open(MM_FILE, 'r') as mm_file:
    mm = yaml.safe_load(mm_file)

with open(IM_FILE, 'r') as im_file:
    im = yaml.safe_load(im_file)

# %% [markdown]
# We need to create first the elements by parsing the metamodel

# %%
classes = { f'{cat_k}_{elem_k}' : elem_v
    for cat_k, cat_v in mm.items()
    for elem_k, elem_v in cat_v.items() 
}

def merge_superclass(elem):
    sc = classes.get(elem.get('superclass'))
    if sc: # merge superclass
        sc_merged = merge_superclass(sc)
        return {
            'attributes': elem.get('attributes', {}) | sc_merged.get('attributes', {}),
            'associations': elem.get('associations', {}) | sc_merged.get('associations', {})
        }
    else: # return the elem
        return elem

# all the elements with all the inherited attributes and associations
merged_classes = {
    elem_k : merge_superclass(elem_v)
    for elem_k, elem_v in classes.items()
}

# %%
@dataclass
class Class:
    name: str
    attributes: dict[str, dict]
    associations: dict[str, dict]
    ref: Optional[SortRef] = None

@dataclass
class Elem:
    id: str
    name: Optional[str]
    attributes: dict[str, dict]
    associations: dict[str, dict]
    eClass: Optional[Class] = None
    ref: Optional[SortRef] = None
    unbound: bool = False

@dataclass
class AssocRel:
    from_elem: Class
    to_elem: Class
    inverse_of: Optional[str]
    ref: Optional[FuncDeclRef] = None

@dataclass
class AttrRel:
    multiplicity: str
    type: str
    ref: Optional[FuncDeclRef] = None

# Convert ELEMS
CLASSES = {
    class_k : Class(
        class_k, 
        class_v.get('attributes', {}), 
        class_v.get('associations', {})
    )
    for class_k, class_v in merged_classes.items()
}

ELEMS = {
    elem_k : Elem(
        elem_v['id'],
        elem_v['name'],
        elem_v['attrs'],
        elem_v['assocs'],
        CLASSES[elem_v['class']],
    )
    for elem_k, elem_v in im.items()
}

# This also helps catching errors in class/assoc names
ASSOCS = {
    f'{class_k}::{assoc_k}' : AssocRel(class_v, CLASSES[assoc_v['class']], assoc_v.get('inverse_of', None))
    for class_k, class_v in CLASSES.items()
    for assoc_k, assoc_v in class_v.associations.items()
}

# Careful: I decided to default multiplicity to 0..1
ATTRS = {
    f'{class_k}::{attr_k}' : AttrRel(attr_v.get('multiplicity', '0..1'), attr_v['type'])
    for class_k, class_v in CLASSES.items()
    for attr_k, attr_v in class_v.attributes.items()
}

# %% [markdown]
# Visualization of all the Elems and Assocs

# %%
classes_df = pd.DataFrame.from_dict([
    {
        'name': name
    }
    for name, value in CLASSES.items()
])

classes_df
# Out:
#                                        name
# 0                       commons_DOMLElement
# 1                          commons_Property
# 2                         commons_IProperty
# 3                         commons_SProperty
# 4                         commons_FProperty
# 5                         commons_BProperty
# 6                     commons_Configuration
# 7                        commons_Deployment
# 8              application_ApplicationLayer
# 9          application_ApplicationComponent
# 10            application_SoftwareComponent
# 11                         application_SaaS
# 12            application_SoftwareInterface
# 13                         application_DBMS
# 14                     application_SaaSDBMS
# 15       infrastructure_InfrastructureLayer
# 16     infrastructure_InfrastructureElement
# 17             infrastructure_ComputingNode
# 18     infrastructure_PhysicalComputingNode
# 19            infrastructure_VirtualMachine
# 20                  infrastructure_Location
# 21                 infrastructure_Container
# 22    infrastructure_ComputingNodeGenerator
# 23                   infrastructure_VMImage
# 24            infrastructure_ContainerImage
# 25          infrastructure_AutoScalingGroup
# 26                   infrastructure_Storage
# 27        infrastructure_FunctionAsAService
# 28                   infrastructure_Network
# 29                    infrastructure_Subnet
# 30          infrastructure_NetworkInterface
# 31           infrastructure_InternetGateway
# 32            infrastructure_ComputingGroup
# 33             infrastructure_SecurityGroup
# 34                      infrastructure_Rule
# 35               infrastructure_Credentials
# 36                   infrastructure_KeyPair
# 37                  infrastructure_UserPass
# 38                 infrastructure_SwarmRole
# 39                     infrastructure_Swarm
# 40  infrastructure_ExtInfrastructureElement
# 41          concrete_ConcreteInfrastructure
# 42                 concrete_ConcreteElement
# 43                 concrete_RuntimeProvider
# 44                  concrete_VirtualMachine
# 45                         concrete_VMImage
# 46                  concrete_ContainerImage
# 47                         concrete_Network
# 48                         concrete_Storage
# 49              concrete_FunctionAsAService
# 50                  concrete_ComputingGroup

# %%
assoc_df = pd.DataFrame.from_dict([
    {
        'name': name,
        'from': value.from_elem.name,
        'to': value.to_elem.name,
        'inverse': value.inverse_of
    }
    for name, value in ASSOCS.items()
])

assoc_df[['from', 'name', 'to', 'inverse']]
# Out:
#                                         from  \
# 0                        commons_DOMLElement
# 1                           commons_Property
# 2                          commons_IProperty
# 3                          commons_SProperty
# 4                          commons_FProperty
# 5                          commons_BProperty
# 6                      commons_Configuration
# 7                      commons_Configuration
# 8                         commons_Deployment
# 9                         commons_Deployment
# 10              application_ApplicationLayer
# 11              application_ApplicationLayer
# 12          application_ApplicationComponent
# 13             application_SoftwareComponent
# 14             application_SoftwareComponent
# 15             application_SoftwareComponent
# 16                          application_SaaS
# 17                          application_SaaS
# 18             application_SoftwareInterface
# 19                          application_DBMS
# 20                          application_DBMS
# 21                          application_DBMS
# 22                      application_SaaSDBMS
# 23                      application_SaaSDBMS
# 24        infrastructure_InfrastructureLayer
# 25        infrastructure_InfrastructureLayer
# 26        infrastructure_InfrastructureLayer
# 27        infrastructure_InfrastructureLayer
# 28        infrastructure_InfrastructureLayer
# 29        infrastructure_InfrastructureLayer
# 30        infrastructure_InfrastructureLayer
# 31        infrastructure_InfrastructureLayer
# 32        infrastructure_InfrastructureLayer
# 33      infrastructure_InfrastructureElement
# 34              infrastructure_ComputingNode
# 35              infrastructure_ComputingNode
# 36              infrastructure_ComputingNode
# 37              infrastructure_ComputingNode
# 38              infrastructure_ComputingNode
# 39      infrastructure_PhysicalComputingNode
# 40      infrastructure_PhysicalComputingNode
# 41      infrastructure_PhysicalComputingNode
# 42      infrastructure_PhysicalComputingNode
# 43      infrastructure_PhysicalComputingNode
# 44             infrastructure_VirtualMachine
# 45             infrastructure_VirtualMachine
# 46             infrastructure_VirtualMachine
# 47             infrastructure_VirtualMachine
# 48             infrastructure_VirtualMachine
# 49             infrastructure_VirtualMachine
# 50                   infrastructure_Location
# 51                  infrastructure_Container
# 52                  infrastructure_Container
# 53                  infrastructure_Container
# 54                  infrastructure_Container
# 55                  infrastructure_Container
# 56                  infrastructure_Container
# 57                  infrastructure_Container
# 58     infrastructure_ComputingNodeGenerator
# 59                    infrastructure_VMImage
# 60                    infrastructure_VMImage
# 61             infrastructure_ContainerImage
# 62             infrastructure_ContainerImage
# 63           infrastructure_AutoScalingGroup
# 64           infrastructure_AutoScalingGroup
# 65           infrastructure_AutoScalingGroup
# 66           infrastructure_AutoScalingGroup
# 67           infrastructure_AutoScalingGroup
# 68                    infrastructure_Storage
# 69                    infrastructure_Storage
# 70         infrastructure_FunctionAsAService
# 71         infrastructure_FunctionAsAService
# 72                    infrastructure_Network
# 73                    infrastructure_Network
# 74                    infrastructure_Network
# 75                    infrastructure_Network
# 76                     infrastructure_Subnet
# 77                     infrastructure_Subnet
# 78                     infrastructure_Subnet
# 79                     infrastructure_Subnet
# 80                     infrastructure_Subnet
# 81           infrastructure_NetworkInterface
# 82           infrastructure_NetworkInterface
# 83           infrastructure_NetworkInterface
# 84            infrastructure_InternetGateway
# 85            infrastructure_InternetGateway
# 86            infrastructure_InternetGateway
# 87             infrastructure_ComputingGroup
# 88             infrastructure_ComputingGroup
# 89              infrastructure_SecurityGroup
# 90              infrastructure_SecurityGroup
# 91              infrastructure_SecurityGroup
# 92                       infrastructure_Rule
# 93                infrastructure_Credentials
# 94                    infrastructure_KeyPair
# 95                   infrastructure_UserPass
# 96                  infrastructure_SwarmRole
# 97                  infrastructure_SwarmRole
# 98                      infrastructure_Swarm
# 99                      infrastructure_Swarm
# 100                     infrastructure_Swarm
# 101  infrastructure_ExtInfrastructureElement
# 102          concrete_ConcreteInfrastructure
# 103          concrete_ConcreteInfrastructure
# 104                 concrete_ConcreteElement
# 105                 concrete_RuntimeProvider
# 106                 concrete_RuntimeProvider
# 107                 concrete_RuntimeProvider
# 108                 concrete_RuntimeProvider
# 109                 concrete_RuntimeProvider
# 110                 concrete_RuntimeProvider
# 111                 concrete_RuntimeProvider
# 112                 concrete_RuntimeProvider
# 113                  concrete_VirtualMachine
# 114                  concrete_VirtualMachine
# 115                         concrete_VMImage
# 116                         concrete_VMImage
# 117                  concrete_ContainerImage
# 118                  concrete_ContainerImage
# 119                         concrete_Network
# 120                         concrete_Network
# 121                         concrete_Storage
# 122                         concrete_Storage
# 123              concrete_FunctionAsAService
# 124              concrete_FunctionAsAService
# 125                  concrete_ComputingGroup
# 126                  concrete_ComputingGroup
#
#                                                   name  \
# 0                     commons_DOMLElement::annotations
# 1                          commons_Property::reference
# 2                         commons_IProperty::reference
# 3                         commons_SProperty::reference
# 4                         commons_FProperty::reference
# 5                         commons_BProperty::reference
# 6                   commons_Configuration::deployments
# 7                   commons_Configuration::annotations
# 8                        commons_Deployment::component
# 9                             commons_Deployment::node
# 10            application_ApplicationLayer::components
# 11           application_ApplicationLayer::annotations
# 12       application_ApplicationComponent::annotations
# 13    application_SoftwareComponent::exposedInterfaces
# 14   application_SoftwareComponent::consumedInterfaces
# 15          application_SoftwareComponent::annotations
# 16                 application_SaaS::exposedInterfaces
# 17                       application_SaaS::annotations
# 18          application_SoftwareInterface::annotations
# 19                 application_DBMS::exposedInterfaces
# 20                application_DBMS::consumedInterfaces
# 21                       application_DBMS::annotations
# 22             application_SaaSDBMS::exposedInterfaces
# 23                   application_SaaSDBMS::annotations
# 24           infrastructure_InfrastructureLayer::nodes
# 25      infrastructure_InfrastructureLayer::generators
# 26        infrastructure_InfrastructureLayer::storages
# 27            infrastructure_InfrastructureLayer::faas
# 28     infrastructure_InfrastructureLayer::credentials
# 29          infrastructure_InfrastructureLayer::groups
# 30   infrastructure_InfrastructureLayer::securityGr...
# 31        infrastructure_InfrastructureLayer::networks
# 32     infrastructure_InfrastructureLayer::annotations
# 33   infrastructure_InfrastructureElement::annotations
# 34                infrastructure_ComputingNode::ifaces
# 35              infrastructure_ComputingNode::location
# 36           infrastructure_ComputingNode::credentials
# 37                 infrastructure_ComputingNode::group
# 38           infrastructure_ComputingNode::annotations
# 39        infrastructure_PhysicalComputingNode::ifaces
# 40      infrastructure_PhysicalComputingNode::location
# 41   infrastructure_PhysicalComputingNode::credentials
# 42         infrastructure_PhysicalComputingNode::group
# 43   infrastructure_PhysicalComputingNode::annotations
# 44        infrastructure_VirtualMachine::generatedFrom
# 45               infrastructure_VirtualMachine::ifaces
# 46             infrastructure_VirtualMachine::location
# 47          infrastructure_VirtualMachine::credentials
# 48                infrastructure_VirtualMachine::group
# 49          infrastructure_VirtualMachine::annotations
# 50                infrastructure_Location::annotations
# 51             infrastructure_Container::generatedFrom
# 52                     infrastructure_Container::hosts
# 53                    infrastructure_Container::ifaces
# 54                  infrastructure_Container::location
# 55               infrastructure_Container::credentials
# 56                     infrastructure_Container::group
# 57               infrastructure_Container::annotations
# 58   infrastructure_ComputingNodeGenerator::annotat...
# 59                infrastructure_VMImage::generatedVMs
# 60                 infrastructure_VMImage::annotations
# 61   infrastructure_ContainerImage::generatedContai...
# 62          infrastructure_ContainerImage::annotations
# 63   infrastructure_AutoScalingGroup::machineDefini...
# 64   infrastructure_AutoScalingGroup::deploymentNet...
# 65      infrastructure_AutoScalingGroup::securityGroup
# 66       infrastructure_AutoScalingGroup::groupedNodes
# 67        infrastructure_AutoScalingGroup::annotations
# 68                      infrastructure_Storage::ifaces
# 69                 infrastructure_Storage::annotations
# 70           infrastructure_FunctionAsAService::ifaces
# 71      infrastructure_FunctionAsAService::annotations
# 72             infrastructure_Network::connectedIfaces
# 73                        infrastructure_Network::igws
# 74                     infrastructure_Network::subnets
# 75                 infrastructure_Network::annotations
# 76                  infrastructure_Subnet::connectedTo
# 77              infrastructure_Subnet::connectedIfaces
# 78                         infrastructure_Subnet::igws
# 79                      infrastructure_Subnet::subnets
# 80                  infrastructure_Subnet::annotations
# 81          infrastructure_NetworkInterface::belongsTo
# 82         infrastructure_NetworkInterface::associated
# 83        infrastructure_NetworkInterface::annotations
# 84           infrastructure_InternetGateway::belongsTo
# 85          infrastructure_InternetGateway::associated
# 86         infrastructure_InternetGateway::annotations
# 87         infrastructure_ComputingGroup::groupedNodes
# 88          infrastructure_ComputingGroup::annotations
# 89                 infrastructure_SecurityGroup::rules
# 90                infrastructure_SecurityGroup::ifaces
# 91           infrastructure_SecurityGroup::annotations
# 92                    infrastructure_Rule::annotations
# 93             infrastructure_Credentials::annotations
# 94                 infrastructure_KeyPair::annotations
# 95                infrastructure_UserPass::annotations
# 96                     infrastructure_SwarmRole::nodes
# 97               infrastructure_SwarmRole::annotations
# 98                         infrastructure_Swarm::roles
# 99                  infrastructure_Swarm::groupedNodes
# 100                  infrastructure_Swarm::annotations
# 101  infrastructure_ExtInfrastructureElement::annot...
# 102         concrete_ConcreteInfrastructure::providers
# 103       concrete_ConcreteInfrastructure::annotations
# 104              concrete_ConcreteElement::annotations
# 105                      concrete_RuntimeProvider::vms
# 106                 concrete_RuntimeProvider::vmImages
# 107          concrete_RuntimeProvider::containerImages
# 108                 concrete_RuntimeProvider::networks
# 109                 concrete_RuntimeProvider::storages
# 110                     concrete_RuntimeProvider::faas
# 111                    concrete_RuntimeProvider::group
# 112              concrete_RuntimeProvider::annotations
# 113                      concrete_VirtualMachine::maps
# 114               concrete_VirtualMachine::annotations
# 115                             concrete_VMImage::maps
# 116                      concrete_VMImage::annotations
# 117                      concrete_ContainerImage::maps
# 118               concrete_ContainerImage::annotations
# 119                             concrete_Network::maps
# 120                      concrete_Network::annotations
# 121                             concrete_Storage::maps
# 122                      concrete_Storage::annotations
# 123                  concrete_FunctionAsAService::maps
# 124           concrete_FunctionAsAService::annotations
# 125                      concrete_ComputingGroup::maps
# 126               concrete_ComputingGroup::annotations
#
#                                         to  \
# 0                         commons_Property
# 1                      commons_DOMLElement
# 2                      commons_DOMLElement
# 3                      commons_DOMLElement
# 4                      commons_DOMLElement
# 5                      commons_DOMLElement
# 6                       commons_Deployment
# 7                         commons_Property
# 8         application_ApplicationComponent
# 9     infrastructure_InfrastructureElement
# 10        application_ApplicationComponent
# 11                        commons_Property
# 12                        commons_Property
# 13           application_SoftwareInterface
# 14           application_SoftwareInterface
# 15                        commons_Property
# 16           application_SoftwareInterface
# 17                        commons_Property
# 18                        commons_Property
# 19           application_SoftwareInterface
# 20           application_SoftwareInterface
# 21                        commons_Property
# 22           application_SoftwareInterface
# 23                        commons_Property
# 24            infrastructure_ComputingNode
# 25   infrastructure_ComputingNodeGenerator
# 26                  infrastructure_Storage
# 27       infrastructure_FunctionAsAService
# 28              infrastructure_Credentials
# 29           infrastructure_ComputingGroup
# 30            infrastructure_SecurityGroup
# 31                  infrastructure_Network
# 32                        commons_Property
# 33                        commons_Property
# 34         infrastructure_NetworkInterface
# 35                 infrastructure_Location
# 36              infrastructure_Credentials
# 37           infrastructure_ComputingGroup
# 38                        commons_Property
# 39         infrastructure_NetworkInterface
# 40                 infrastructure_Location
# 41              infrastructure_Credentials
# 42           infrastructure_ComputingGroup
# 43                        commons_Property
# 44                  infrastructure_VMImage
# 45         infrastructure_NetworkInterface
# 46                 infrastructure_Location
# 47              infrastructure_Credentials
# 48           infrastructure_ComputingGroup
# 49                        commons_Property
# 50                        commons_Property
# 51           infrastructure_ContainerImage
# 52            infrastructure_ComputingNode
# 53         infrastructure_NetworkInterface
# 54                 infrastructure_Location
# 55              infrastructure_Credentials
# 56           infrastructure_ComputingGroup
# 57                        commons_Property
# 58                        commons_Property
# 59           infrastructure_VirtualMachine
# 60                        commons_Property
# 61                infrastructure_Container
# 62                        commons_Property
# 63           infrastructure_VirtualMachine
# 64                  infrastructure_Network
# 65            infrastructure_SecurityGroup
# 66            infrastructure_ComputingNode
# 67                        commons_Property
# 68         infrastructure_NetworkInterface
# 69                        commons_Property
# 70         infrastructure_NetworkInterface
# 71                        commons_Property
# 72         infrastructure_NetworkInterface
# 73          infrastructure_InternetGateway
# 74                   infrastructure_Subnet
# 75                        commons_Property
# 76                  infrastructure_Network
# 77         infrastructure_NetworkInterface
# 78          infrastructure_InternetGateway
# 79                   infrastructure_Subnet
# 80                        commons_Property
# 81                  infrastructure_Network
# 82            infrastructure_SecurityGroup
# 83                        commons_Property
# 84                  infrastructure_Network
# 85            infrastructure_SecurityGroup
# 86                        commons_Property
# 87            infrastructure_ComputingNode
# 88                        commons_Property
# 89                     infrastructure_Rule
# 90         infrastructure_NetworkInterface
# 91                        commons_Property
# 92                        commons_Property
# 93                        commons_Property
# 94                        commons_Property
# 95                        commons_Property
# 96            infrastructure_ComputingNode
# 97                        commons_Property
# 98                infrastructure_SwarmRole
# 99            infrastructure_ComputingNode
# 100                       commons_Property
# 101                       commons_Property
# 102               concrete_RuntimeProvider
# 103                       commons_Property
# 104                       commons_Property
# 105                concrete_VirtualMachine
# 106                       concrete_VMImage
# 107                concrete_ContainerImage
# 108                       concrete_Network
# 109                       concrete_Storage
# 110            concrete_FunctionAsAService
# 111                concrete_ComputingGroup
# 112                       commons_Property
# 113          infrastructure_VirtualMachine
# 114                       commons_Property
# 115                 infrastructure_VMImage
# 116                       commons_Property
# 117          infrastructure_ContainerImage
# 118                       commons_Property
# 119                 infrastructure_Network
# 120                       commons_Property
# 121                 infrastructure_Storage
# 122                       commons_Property
# 123      infrastructure_FunctionAsAService
# 124                       commons_Property
# 125          infrastructure_ComputingGroup
# 126                       commons_Property
#
#                                           inverse
# 0                                            None
# 1                                            None
# 2                                            None
# 3                                            None
# 4                                            None
# 5                                            None
# 6                                            None
# 7                                            None
# 8                                            None
# 9                                            None
# 10                                           None
# 11                                           None
# 12                                           None
# 13                                           None
# 14                                           None
# 15                                           None
# 16                                           None
# 17                                           None
# 18                                           None
# 19                                           None
# 20                                           None
# 21                                           None
# 22                                           None
# 23                                           None
# 24                                           None
# 25                                           None
# 26                                           None
# 27                                           None
# 28                                           None
# 29                                           None
# 30                                           None
# 31                                           None
# 32                                           None
# 33                                           None
# 34                                           None
# 35                                           None
# 36                                           None
# 37    infrastructure_ComputingGroup::groupedNodes
# 38                                           None
# 39                                           None
# 40                                           None
# 41                                           None
# 42    infrastructure_ComputingGroup::groupedNodes
# 43                                           None
# 44                                           None
# 45                                           None
# 46                                           None
# 47                                           None
# 48    infrastructure_ComputingGroup::groupedNodes
# 49                                           None
# 50                                           None
# 51                                           None
# 52                                           None
# 53                                           None
# 54                                           None
# 55                                           None
# 56    infrastructure_ComputingGroup::groupedNodes
# 57                                           None
# 58                                           None
# 59   infrastructure_VirtualMachine::generatedFrom
# 60                                           None
# 61        infrastructure_Container::generatedFrom
# 62                                           None
# 63                                           None
# 64                                           None
# 65                                           None
# 66            infrastructure_ComputingNode::group
# 67                                           None
# 68                                           None
# 69                                           None
# 70                                           None
# 71                                           None
# 72     infrastructure_NetworkInterface::belongsTo
# 73                                           None
# 74                                           None
# 75                                           None
# 76                                           None
# 77     infrastructure_NetworkInterface::belongsTo
# 78                                           None
# 79                                           None
# 80                                           None
# 81                                           None
# 82                                           None
# 83                                           None
# 84                                           None
# 85                                           None
# 86                                           None
# 87            infrastructure_ComputingNode::group
# 88                                           None
# 89                                           None
# 90    infrastructure_NetworkInterface::associated
# 91                                           None
# 92                                           None
# 93                                           None
# 94                                           None
# 95                                           None
# 96                                           None
# 97                                           None
# 98                                           None
# 99            infrastructure_ComputingNode::group
# 100                                          None
# 101                                          None
# 102                                          None
# 103                                          None
# 104                                          None
# 105                                          None
# 106                                          None
# 107                                          None
# 108                                          None
# 109                                          None
# 110                                          None
# 111                                          None
# 112                                          None
# 113                                          None
# 114                                          None
# 115                                          None
# 116                                          None
# 117                                          None
# 118                                          None
# 119                                          None
# 120                                          None
# 121                                          None
# 122                                          None
# 123                                          None
# 124                                          None
# 125                                          None
# 126                                          None

# %% [markdown]
# ### Z3 Enum Definitions
# Here we define the Sorts of Elements and Associations as Enums (as they are finite), and the relationship between two elements as a Function `AssocRel :: ElemSort, AssocSort, ElemSort -> BoolSort`, which tells us if two items are in a relationship (returns true) or not.

# %%
# Init Z3 solver
s = Solver()

def Iff(a, b):
    return a == b

# %%
ub_elems = { f'elem_ub_{i}' : Elem(
    f'elem_ub_{i}',
    f'Unbound Element #{i}',
    {},
    {},
    unbound=True
    ) 
    for i in range(UB_ELEMS)
}

# %%
class_sort, classes = EnumSort('Class', list(CLASSES.keys()))
# Add the Ref to each ELEM
for c in classes:
    CLASSES[str(c)].ref = c

elem_sort, elems = EnumSort('Elem', list((ELEMS | ub_elems).keys()))
for elem in elems:
    ELEMS[str(elem)].ref = elem

# Where assoc_sort is an EnumSort of all associations names...
assoc_sort, assocs = EnumSort('Assoc', list(ASSOCS.keys()))
# Add the Ref to each ASSOC
for assoc in assocs:
    ASSOCS[str(assoc)].ref = assoc

attr_sort, attrs = EnumSort('Attr', list(ATTRS.keys()))
# Add the Ref to each ATTR
for attr in attrs:
    ATTRS[str(attr)].ref = attr

# %%
# ElemClass(Elem) -> Class
elem_class_fn = Function('ElemClass', elem_sort, class_sort)

for _, elem in ELEMS.items():
    if not elem.unbound:
        user_friendly_name = f'({elem.name})' if elem.name else ''
        s.assert_and_track(elem_class_fn(elem.ref) == elem.eClass.ref, f'ElemClass {elem.id}{user_friendly_name} {elem.eClass.name}')

# %%
# AssocRel(Elem, Assoc, Elem) -> Bool
assoc_rel = Function('AssocRel', elem_sort, assoc_sort, elem_sort, BoolSort())

assoc_a = Const('assoc_a', assoc_sort)
for (_, e1), (_, e2) in product(ELEMS.items(), ELEMS.items()):
    if not e1.unbound and not e2.unbound:
        stmt = ForAll(
            [assoc_a],
            Iff(
                assoc_rel(e1.ref, assoc_a, e2.ref),
                Or(
                    *(
                        assoc_a == ASSOCS[e1_assoc_k].ref
                        for e1_assoc_k, e1_assoc_v in e1.associations.items()
                        if e2.id in e1_assoc_v
                    )
                )
            )
        )
        s.assert_and_track(stmt, f'AssocRel {e1.id} {e2.id}')

# %%
assert(s.check() == sat)

# %% [markdown]
# Since we're done with the setup, we need to be sure that the base model is satisfiable!
