# %%
from z3 import *

import yaml
import pandas as pd

from dataclasses import dataclass
from pprint import pprint
from typing import Optional
from itertools import product

pd.set_option('display.max_rows', None)

# %%
MM_FILE = './assets/metamodels/doml_meta_v2.0.yaml'

IM_FILE = './assets/doml/2.0/nginx-openstack_v2.0.yaml'
# IM_FILE = './assets/doml/2.0/nginx-openstack_v2.0_wrong_vm_iface.yaml'

UB_ELEMS = 0

# %%
with open(MM_FILE, 'r') as mm_file:
    mm = yaml.safe_load(mm_file)

with open(IM_FILE, 'r') as im_file:
    im = yaml.safe_load(im_file)

# %% [markdown]
# We need to create first the elements by parsing the metamodel

# %%
classes = { f'{cat_k}_{elem_k}' : elem_v
    for cat_k, cat_v in mm.items()
    for elem_k, elem_v in cat_v.items() 
}

def merge_superclass(elem):
    e_k, e_v = elem
    sc_k = e_v.get('superclass')
    sc_v = classes.get(sc_k)
    if not sc_k:
        e_v['associations'] = {f'{e_k}::{k}': v for k,v in e_v.get('associations',{}).items()}
        e_v['attributes'] = {f'{e_k}::{k}': v for k,v in e_v.get('attributes',{}).items()}
        return e_v
    else:
        e_v['associations'] = {f'{e_k}::{k}': v for k,v in e_v.get('associations',{}).items()} | sc_v.get('associations',{})
        e_v['attributes'] = {f'{e_k}::{k}': v for k,v in e_v.get('attributes',{}).items()} | sc_v.get('attributes',{})
        return e_v

# all the elements with all the inherited attributes and associations
merged_classes = { 
    k : merge_superclass((k,v))
    for k,v in classes.items()
}

# %%
@dataclass
class Class:
    name: str
    attributes: dict[str, dict]
    associations: dict[str, dict]
    ref: Optional[SortRef] = None

@dataclass
class Elem:
    id: str
    name: Optional[str]
    attributes: dict[str, dict]
    associations: dict[str, dict]
    eClass: Optional[Class] = None
    ref: Optional[SortRef] = None
    unbound: bool = False

@dataclass
class AssocRel:
    from_elem: Class
    to_elem: Class
    inverse_of: Optional[str]
    ref: Optional[FuncDeclRef] = None

@dataclass
class AttrRel:
    multiplicity: str
    type: str
    ref: Optional[FuncDeclRef] = None

# Convert ELEMS
CLASSES = {
    class_k : Class(
        class_k, 
        class_v.get('attributes', {}), 
        class_v.get('associations', {})
    )
    for class_k, class_v in merged_classes.items()
}

ELEMS = {
    elem_k : Elem(
        elem_v['id'],
        elem_v['name'],
        elem_v['attrs'],
        elem_v['assocs'],
        CLASSES[elem_v['class']],
    )
    for elem_k, elem_v in im.items()
}

# This also helps catching errors in class/assoc names
ASSOCS = {
    f'{assoc_k}' : AssocRel(class_v, CLASSES[assoc_v['class']], assoc_v.get('inverse_of', None))
    for class_k, class_v in CLASSES.items()
    for assoc_k, assoc_v in class_v.associations.items()
}

# Careful: I decided to default multiplicity to 0..1
ATTRS = {
    f'{attr_k}' : AttrRel(attr_v.get('multiplicity', '0..1'), attr_v['type'])
    for class_k, class_v in CLASSES.items()
    for attr_k, attr_v in class_v.attributes.items()
}

# %% [markdown]
# Visualization of all the Elems and Assocs

# %%
classes_df = pd.DataFrame.from_dict([
    {
        'name': name
    }
    for name, value in CLASSES.items()
])

classes_df
# Out:
#                                        name
# 0                       commons_DOMLElement
# 1                          commons_Property
# 2                         commons_IProperty
# 3                         commons_SProperty
# 4                         commons_FProperty
# 5                         commons_BProperty
# 6                     commons_Configuration
# 7                        commons_Deployment
# 8              application_ApplicationLayer
# 9          application_ApplicationComponent
# 10            application_SoftwareComponent
# 11                         application_SaaS
# 12            application_SoftwareInterface
# 13                         application_DBMS
# 14                     application_SaaSDBMS
# 15       infrastructure_InfrastructureLayer
# 16     infrastructure_InfrastructureElement
# 17             infrastructure_ComputingNode
# 18     infrastructure_PhysicalComputingNode
# 19            infrastructure_VirtualMachine
# 20                  infrastructure_Location
# 21                 infrastructure_Container
# 22    infrastructure_ComputingNodeGenerator
# 23                   infrastructure_VMImage
# 24            infrastructure_ContainerImage
# 25          infrastructure_AutoScalingGroup
# 26                   infrastructure_Storage
# 27        infrastructure_FunctionAsAService
# 28                   infrastructure_Network
# 29                    infrastructure_Subnet
# 30          infrastructure_NetworkInterface
# 31           infrastructure_InternetGateway
# 32            infrastructure_ComputingGroup
# 33             infrastructure_SecurityGroup
# 34                      infrastructure_Rule
# 35               infrastructure_Credentials
# 36                   infrastructure_KeyPair
# 37                  infrastructure_UserPass
# 38                 infrastructure_SwarmRole
# 39                     infrastructure_Swarm
# 40  infrastructure_ExtInfrastructureElement
# 41          concrete_ConcreteInfrastructure
# 42                 concrete_ConcreteElement
# 43                 concrete_RuntimeProvider
# 44                  concrete_VirtualMachine
# 45                         concrete_VMImage
# 46                  concrete_ContainerImage
# 47                         concrete_Network
# 48                         concrete_Storage
# 49              concrete_FunctionAsAService
# 50                  concrete_ComputingGroup

# %%
assoc_df = pd.DataFrame.from_dict([
    {
        'name': name,
        'from': value.from_elem.name,
        'to': value.to_elem.name,
        'inverse': value.inverse_of
    }
    for name, value in ASSOCS.items()
])

assoc_df[['from', 'name', 'to', 'inverse']]
# Out:
#                                   from  \
# 0              concrete_ComputingGroup
# 1                    commons_BProperty
# 2                commons_Configuration
# 3                   commons_Deployment
# 4                   commons_Deployment
# 5         application_ApplicationLayer
# 6                     application_DBMS
# 7                     application_DBMS
# 8                 application_SaaSDBMS
# 9   infrastructure_InfrastructureLayer
# 10  infrastructure_InfrastructureLayer
# 11  infrastructure_InfrastructureLayer
# 12  infrastructure_InfrastructureLayer
# 13  infrastructure_InfrastructureLayer
# 14  infrastructure_InfrastructureLayer
# 15  infrastructure_InfrastructureLayer
# 16  infrastructure_InfrastructureLayer
# 17            infrastructure_Container
# 18            infrastructure_Container
# 19            infrastructure_Container
# 20            infrastructure_Container
# 21       infrastructure_VirtualMachine
# 22            infrastructure_Container
# 23            infrastructure_Container
# 24              infrastructure_VMImage
# 25       infrastructure_ContainerImage
# 26     infrastructure_AutoScalingGroup
# 27     infrastructure_AutoScalingGroup
# 28     infrastructure_AutoScalingGroup
# 29     infrastructure_AutoScalingGroup
# 30              infrastructure_Storage
# 31   infrastructure_FunctionAsAService
# 32               infrastructure_Subnet
# 33               infrastructure_Subnet
# 34               infrastructure_Subnet
# 35               infrastructure_Subnet
# 36      infrastructure_InternetGateway
# 37      infrastructure_InternetGateway
# 38                infrastructure_Swarm
# 39        infrastructure_SecurityGroup
# 40        infrastructure_SecurityGroup
# 41            infrastructure_SwarmRole
# 42                infrastructure_Swarm
# 43     concrete_ConcreteInfrastructure
# 44            concrete_RuntimeProvider
# 45            concrete_RuntimeProvider
# 46            concrete_RuntimeProvider
# 47            concrete_RuntimeProvider
# 48            concrete_RuntimeProvider
# 49            concrete_RuntimeProvider
# 50            concrete_RuntimeProvider
# 51             concrete_VirtualMachine
# 52                    concrete_VMImage
# 53             concrete_ContainerImage
# 54                    concrete_Network
# 55                    concrete_Storage
# 56         concrete_FunctionAsAService
# 57             concrete_ComputingGroup
#
#                                                  name  \
# 0                    commons_DOMLElement::annotations
# 1                         commons_Property::reference
# 2                  commons_Configuration::deployments
# 3                       commons_Deployment::component
# 4                            commons_Deployment::node
# 5            application_ApplicationLayer::components
# 6    application_SoftwareComponent::exposedInterfaces
# 7   application_SoftwareComponent::consumedInterfaces
# 8                 application_SaaS::exposedInterfaces
# 9           infrastructure_InfrastructureLayer::nodes
# 10     infrastructure_InfrastructureLayer::generators
# 11       infrastructure_InfrastructureLayer::storages
# 12           infrastructure_InfrastructureLayer::faas
# 13    infrastructure_InfrastructureLayer::credentials
# 14         infrastructure_InfrastructureLayer::groups
# 15  infrastructure_InfrastructureLayer::securityGr...
# 16       infrastructure_InfrastructureLayer::networks
# 17               infrastructure_ComputingNode::ifaces
# 18             infrastructure_ComputingNode::location
# 19          infrastructure_ComputingNode::credentials
# 20                infrastructure_ComputingNode::group
# 21       infrastructure_VirtualMachine::generatedFrom
# 22            infrastructure_Container::generatedFrom
# 23                    infrastructure_Container::hosts
# 24               infrastructure_VMImage::generatedVMs
# 25  infrastructure_ContainerImage::generatedContai...
# 26  infrastructure_AutoScalingGroup::machineDefini...
# 27  infrastructure_AutoScalingGroup::deploymentNet...
# 28     infrastructure_AutoScalingGroup::securityGroup
# 29                                       groupedNodes
# 30                     infrastructure_Storage::ifaces
# 31          infrastructure_FunctionAsAService::ifaces
# 32            infrastructure_Network::connectedIfaces
# 33                       infrastructure_Network::igws
# 34                    infrastructure_Network::subnets
# 35                 infrastructure_Subnet::connectedTo
# 36         infrastructure_NetworkInterface::belongsTo
# 37        infrastructure_NetworkInterface::associated
# 38        infrastructure_ComputingGroup::groupedNodes
# 39                infrastructure_SecurityGroup::rules
# 40               infrastructure_SecurityGroup::ifaces
# 41                    infrastructure_SwarmRole::nodes
# 42                        infrastructure_Swarm::roles
# 43         concrete_ConcreteInfrastructure::providers
# 44                      concrete_RuntimeProvider::vms
# 45                 concrete_RuntimeProvider::vmImages
# 46          concrete_RuntimeProvider::containerImages
# 47                 concrete_RuntimeProvider::networks
# 48                 concrete_RuntimeProvider::storages
# 49                     concrete_RuntimeProvider::faas
# 50                    concrete_RuntimeProvider::group
# 51                      concrete_VirtualMachine::maps
# 52                             concrete_VMImage::maps
# 53                      concrete_ContainerImage::maps
# 54                             concrete_Network::maps
# 55                             concrete_Storage::maps
# 56                  concrete_FunctionAsAService::maps
# 57                      concrete_ComputingGroup::maps
#
#                                        to  \
# 0                        commons_Property
# 1                     commons_DOMLElement
# 2                      commons_Deployment
# 3        application_ApplicationComponent
# 4    infrastructure_InfrastructureElement
# 5        application_ApplicationComponent
# 6           application_SoftwareInterface
# 7           application_SoftwareInterface
# 8           application_SoftwareInterface
# 9            infrastructure_ComputingNode
# 10  infrastructure_ComputingNodeGenerator
# 11                 infrastructure_Storage
# 12      infrastructure_FunctionAsAService
# 13             infrastructure_Credentials
# 14          infrastructure_ComputingGroup
# 15           infrastructure_SecurityGroup
# 16                 infrastructure_Network
# 17        infrastructure_NetworkInterface
# 18                infrastructure_Location
# 19             infrastructure_Credentials
# 20          infrastructure_ComputingGroup
# 21                 infrastructure_VMImage
# 22          infrastructure_ContainerImage
# 23           infrastructure_ComputingNode
# 24          infrastructure_VirtualMachine
# 25               infrastructure_Container
# 26          infrastructure_VirtualMachine
# 27                 infrastructure_Network
# 28           infrastructure_SecurityGroup
# 29           infrastructure_ComputingNode
# 30        infrastructure_NetworkInterface
# 31        infrastructure_NetworkInterface
# 32        infrastructure_NetworkInterface
# 33         infrastructure_InternetGateway
# 34                  infrastructure_Subnet
# 35                 infrastructure_Network
# 36                 infrastructure_Network
# 37           infrastructure_SecurityGroup
# 38           infrastructure_ComputingNode
# 39                    infrastructure_Rule
# 40        infrastructure_NetworkInterface
# 41           infrastructure_ComputingNode
# 42               infrastructure_SwarmRole
# 43               concrete_RuntimeProvider
# 44                concrete_VirtualMachine
# 45                       concrete_VMImage
# 46                concrete_ContainerImage
# 47                       concrete_Network
# 48                       concrete_Storage
# 49            concrete_FunctionAsAService
# 50                concrete_ComputingGroup
# 51          infrastructure_VirtualMachine
# 52                 infrastructure_VMImage
# 53          infrastructure_ContainerImage
# 54                 infrastructure_Network
# 55                 infrastructure_Storage
# 56      infrastructure_FunctionAsAService
# 57          infrastructure_ComputingGroup
#
#                                          inverse
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
# 5                                           None
# 6                                           None
# 7                                           None
# 8                                           None
# 9                                           None
# 10                                          None
# 11                                          None
# 12                                          None
# 13                                          None
# 14                                          None
# 15                                          None
# 16                                          None
# 17                                          None
# 18                                          None
# 19                                          None
# 20   infrastructure_ComputingGroup::groupedNodes
# 21                                          None
# 22                                          None
# 23                                          None
# 24  infrastructure_VirtualMachine::generatedFrom
# 25       infrastructure_Container::generatedFrom
# 26                                          None
# 27                                          None
# 28                                          None
# 29           infrastructure_ComputingNode::group
# 30                                          None
# 31                                          None
# 32    infrastructure_NetworkInterface::belongsTo
# 33                                          None
# 34                                          None
# 35                                          None
# 36                                          None
# 37                                          None
# 38           infrastructure_ComputingNode::group
# 39                                          None
# 40   infrastructure_NetworkInterface::associated
# 41                                          None
# 42                                          None
# 43                                          None
# 44                                          None
# 45                                          None
# 46                                          None
# 47                                          None
# 48                                          None
# 49                                          None
# 50                                          None
# 51                                          None
# 52                                          None
# 53                                          None
# 54                                          None
# 55                                          None
# 56                                          None
# 57                                          None

# %% [markdown]
# ## Z3 Sort Definitions
# Here we define the Sorts of Elements and Associations as Enums (as they are finite), and the relationship between two elements as a Function `AssocRel :: ElemSort, AssocSort, ElemSort -> BoolSort`, which tells us if two items are in a relationship (returns true) or not.

# %%
# Init Z3 solver
s = Solver()

def Iff(a, b):
    return a == b

# %%
ub_elems = { f'elem_ub_{i}' : Elem(
    f'elem_ub_{i}',
    f'Unbound Element #{i}',
    {},
    {},
    unbound=True
    ) 
    for i in range(UB_ELEMS)
}

ELEMS |= ub_elems

# %%
class_sort, classes = EnumSort('Class', list(CLASSES.keys()))
# Add the Ref to each ELEM
for c in classes:
    CLASSES[str(c)].ref = c

elem_sort, elems = EnumSort('Elem', list(ELEMS.keys()))
for elem in elems:
    ELEMS[str(elem)].ref = elem

# Where assoc_sort is an EnumSort of all associations names...
assoc_sort, assocs = EnumSort('Assoc', list(ASSOCS.keys()))
# Add the Ref to each ASSOC
for assoc in assocs:
    ASSOCS[str(assoc)].ref = assoc

attr_sort, attrs = EnumSort('Attr', list(ATTRS.keys()))
# Add the Ref to each ATTR
for attr in attrs:
    ATTRS[str(attr)].ref = attr

# %%
# ElemClass(Elem) -> Class
elem_class_fn = Function('ElemClass', elem_sort, class_sort)

for _, elem in ELEMS.items():
    if not elem.unbound:
        user_friendly_name = f'({elem.name})' if elem.name else ''
        s.assert_and_track(elem_class_fn(elem.ref) == elem.eClass.ref, f'ElemClass {elem.id}{user_friendly_name} {elem.eClass.name}')

# %%
# AssocRel(Elem, Assoc, Elem) -> Bool
assoc_rel = Function('AssocRel', elem_sort, assoc_sort, elem_sort, BoolSort())

assoc_a = Const('assoc_a', assoc_sort)
for (_, e1), (_, e2) in product(ELEMS.items(), ELEMS.items()):
    if (not e1.unbound and not e2.unbound):
        stmt = ForAll(
            [assoc_a],
            Iff(
                assoc_rel(e1.ref, assoc_a, e2.ref),
                Or(
                    *(
                        assoc_a == ASSOCS[e1_assoc_k].ref
                        for e1_assoc_k, e1_assoc_v in e1.associations.items()
                        if e2.id in e1_assoc_v
                    )
                )
            )
        )
        s.assert_and_track(stmt, f'AssocRel {e1.id} {e2.id}')

# %%
# WORKING - 4 Jan 2023 17:30
# # AttrRel(Elem, Attr, Value) -> Bool
# attr_int_rel = Function('AttrIntRel', elem_sort, attr_sort, IntSort(), BoolSort())
# # ...do the others
# attr_a = Const('attr_a', attr_sort)
# attr_value_b = Const('attr_value_b', IntSort())
# for _, elem in ELEMS.items():
#     if elem.eClass:
#         eClassAttrs = elem.eClass.attributes
#         print(f'{elem.id} {elem.name}')
#         for k, v in eClassAttrs.items():
#             if v['type'] == 'Integer':
#                 print('\t', k)
#         stmt = ForAll(
#             [attr_a],
#             Iff(
#                 attr_int_rel(elem.ref, attr_a, attr_value_b),
#                 Or(
#                     *(
#                         attr_a == ATTRS[attr_name].ref
#                         for attr_name, attr_value in eClassAttrs.items()
#                         if attr_value['type'] == 'Integer'
#                     )
#                 )
#             )
#         )
#         s.assert_and_track(stmt, f'AttrIntRel {elem.id} Int')

# TEST - 4 Jan 2023 17:30
# AttrRel(Elem, Attr) -> Bool
# True if Elem has Attr relationship
attr_int_exist_rel = Function('AttrIntExistRel', elem_sort, attr_sort, BoolSort())
# ...do the others
attr_a = Const('attr_a', attr_sort)
for _, elem in ELEMS.items():
    if elem.eClass:
        eClassAttrs = elem.eClass.attributes
        print(f'{elem.id} {elem.name}')
        for k, v in eClassAttrs.items():
            type = v['type']
            print(f'\t{k} ({type})')
        stmt = ForAll(
            [attr_a],
            Iff(
                attr_int_exist_rel(elem.ref, attr_a),
                Or(
                    *(
                        attr_a == ATTRS[attr_name].ref
                        for attr_name, attr_value in eClassAttrs.items()
                        if attr_value['type'] == 'Integer'
                    )
                )
            )
        )
        s.assert_and_track(stmt, f'AttrIntExistRel {elem.id}')
# Out:
# elem_139682453244048 sg
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682453246288 infra
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682453246416 v_img
# 	infrastructure_ComputingNodeGenerator::uri (String)
# 	infrastructure_ComputingNodeGenerator::kind (GeneratorKind)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682453247120 ssh_key
# 	infrastructure_KeyPair::user (String)
# 	infrastructure_KeyPair::keyfile (String)
# 	infrastructure_KeyPair::algorithm (String)
# 	infrastructure_KeyPair::bits (Integer)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682453248016 vm1
# 	infrastructure_VirtualMachine::sizeDescription (String)
# 	infrastructure_ComputingNode::architecture (String)
# 	infrastructure_ComputingNode::os (String)
# 	infrastructure_ComputingNode::memory_mb (Integer)
# 	infrastructure_ComputingNode::memory_kb (Integer)
# 	infrastructure_ComputingNode::storage (String)
# 	infrastructure_ComputingNode::cpu_count (Integer)
# 	infrastructure_ComputingNode::cost (Integer)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682453248272 i1
# 	infrastructure_NetworkInterface::endPoint (Integer)
# 	infrastructure_NetworkInterface::speed (String)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682453252752 None
# 	commons_SProperty::value (String)
# 	commons_Property::key (String)
# elem_139682453252816 nginx
# 	application_SoftwareComponent::isPersistent (Boolean)
# 	application_SoftwareComponent::licenseCost (String)
# 	application_SoftwareComponent::configFile (String)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682453253200 con_infra
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682453254480 ag
# 	infrastructure_AutoScalingGroup::min (Integer)
# 	infrastructure_AutoScalingGroup::max (Integer)
# 	infrastructure_AutoScalingGroup::loadBalancer (String)
# elem_139682454964944 None
# 	commons_SProperty::value (String)
# 	commons_Property::key (String)
# elem_139682454968848 None
# 	commons_SProperty::value (String)
# 	commons_Property::key (String)
# elem_139682454976784 None
# 	commons_SProperty::value (String)
# 	commons_Property::key (String)
# elem_139682454978384 concrete_vm_image
# 	concrete_ConcreteElement::configurationScript (String)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682454978448 concrete_net
# 	concrete_ConcreteElement::configurationScript (String)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682455130192 concrete_vm
# 	concrete_ConcreteElement::configurationScript (String)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682455132112 None
# 	commons_SProperty::value (String)
# 	commons_Property::key (String)
# elem_139682465716176 icmp
# 	infrastructure_Rule::kind (String)
# 	infrastructure_Rule::protocol (String)
# 	infrastructure_Rule::fromPort (Integer)
# 	infrastructure_Rule::toPort (Integer)
# 	infrastructure_Rule::cidr (String)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682465984400 openstack
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682467066960 None
# 	commons_SProperty::value (String)
# 	commons_Property::key (String)
# elem_139682467223760 app
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682467399824 http
# 	infrastructure_Rule::kind (String)
# 	infrastructure_Rule::protocol (String)
# 	infrastructure_Rule::fromPort (Integer)
# 	infrastructure_Rule::toPort (Integer)
# 	infrastructure_Rule::cidr (String)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682467402256 ssh
# 	infrastructure_Rule::kind (String)
# 	infrastructure_Rule::protocol (String)
# 	infrastructure_Rule::fromPort (Integer)
# 	infrastructure_Rule::toPort (Integer)
# 	infrastructure_Rule::cidr (String)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682467408848 https
# 	infrastructure_Rule::kind (String)
# 	infrastructure_Rule::protocol (String)
# 	infrastructure_Rule::fromPort (Integer)
# 	infrastructure_Rule::toPort (Integer)
# 	infrastructure_Rule::cidr (String)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682467580048 config
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)
# elem_139682467588752 None
# elem_139682468739152 net1
# 	infrastructure_Network::protocol (String)
# 	infrastructure_Network::address_lb (Integer)
# 	infrastructure_Network::address_ub (Integer)
# 	commons_DOMLElement::name (String)
# 	commons_DOMLElement::description (String)

# %%
assert(s.check() == sat)

# %% [markdown]
# Since we're done with the setup, we need to be sure that the base model is satisfiable!
#
# Right now we're not checking any requirement. We're just telling the solver which are the valid relationships between stuff.

# %%
vm, iface = Consts("vm iface", elem_sort)

req_vm_iface = ForAll(
    [vm],
    Implies(
        elem_class_fn(vm) == CLASSES["infrastructure_VirtualMachine"].ref,
        Exists(
            [iface],
            And(
                assoc_rel(vm, ASSOCS["infrastructure_ComputingNode::ifaces"].ref, iface)
            )
        )
    )
)
s.assert_and_track(req_vm_iface, "vm_iface")

# %%
vm = Const("vm", elem_sort)
CpuCount = Int("cpucount")

# req_vm_cpucount = ForAll(
#     [vm],
#     Implies(
#         elem_class_fn(vm) == CLASSES["infrastructure_VirtualMachine"].ref,
#         Exists(
#             [CpuCount],
#             And(
#                 attr_int_rel(vm, ATTRS["infrastructure_ComputingNode::cpu_count"].ref, CpuCount),
#                 CpuCount == 5
#             )
#         )
#     )
# )
# s.assert_and_track(req_vm_cpucount, "vm_cpucount")

req_vm_cpucount = ForAll(
    [vm],
    Implies(
        elem_class_fn(vm) == CLASSES["infrastructure_VirtualMachine"].ref,
        
        attr_int_exist_rel(vm, ATTRS["infrastructure_ComputingNode::cpu_count"].ref)
    )
)
s.assert_and_track(req_vm_cpucount, "vm_cpucount")

# %% [markdown]
# In `req_vm_cpucount` when using
# ```python
# attr_int_exist_rel(vm, ATTRS["infrastructure_ComputingNode::cpu_count"].ref)
# ```
# it works (produces *sat*) since `cpu_count` is indeed a property of VM.
#
# If we use another attr. key instead, such as `infrastructure_KeyPair::keyfile`,
# we get *unsat* as a result, which is consistent, since `keyfile` doesn't belong to the
# properties of a VM.

# %%
isSat = s.check()
assert(isSat)
print(isSat)
# Out:
# unsat

# %%
model = s.model()
# Out:
# ---------------------------------------------------------------------------
# Z3Exception                               Traceback (most recent call last)
# File ~/Projects/piacere-synthesis/.venv/lib64/python3.11/site-packages/z3/z3.py:7130, in Solver.model(self)
#    7129 try:
# -> 7130     return ModelRef(Z3_solver_get_model(self.ctx.ref(), self.solver), self.ctx)
#    7131 except Z3Exception:
#
# File ~/Projects/piacere-synthesis/.venv/lib64/python3.11/site-packages/z3/z3core.py:4065, in Z3_solver_get_model(a0, a1, _elems)
#    4064 r = _elems.f(a0, a1)
# -> 4065 _elems.Check(a0)
#    4066 return r
#
# File ~/Projects/piacere-synthesis/.venv/lib64/python3.11/site-packages/z3/z3core.py:1475, in Elementaries.Check(self, ctx)
#    1474 if err != self.OK:
# -> 1475     raise self.Exception(self.get_error_message(ctx, err))
#
# Z3Exception: b'there is no current model'
#
# During handling of the above exception, another exception occurred:
#
# Z3Exception                               Traceback (most recent call last)
# Cell In[322], line 1
# ----> 1 model = s.model()
#
# File ~/Projects/piacere-synthesis/.venv/lib64/python3.11/site-packages/z3/z3.py:7132, in Solver.model(self)
#    7130     return ModelRef(Z3_solver_get_model(self.ctx.ref(), self.solver), self.ctx)
#    7131 except Z3Exception:
# -> 7132     raise Z3Exception("model is not available")
#
# Z3Exception: model is not available

# %%
model_df = pd.DataFrame([str(x).split(' ') for x in list(model)])

model_df.sort_values(by=0)
# Out:
#                    0                                        1  \
# 0           AssocRel                     elem_139682453244048
# 483         AssocRel                     elem_139682454976784
# 484         AssocRel                     elem_139682467402256
# 485         AssocRel                     elem_139682454968848
# 486         AssocRel                     elem_139682453247120
# 751         AssocRel                     elem_139682453246288
# 488         AssocRel                     elem_139682454964944
# 489         AssocRel                     elem_139682453246288
# 490         AssocRel                     elem_139682465984400
# 482         AssocRel                     elem_139682453246416
# 491         AssocRel                     elem_139682467588752
# 493         AssocRel                     elem_139682453254480
# 494         AssocRel                     elem_139682465984400
# 495         AssocRel                     elem_139682453248272
# 496         AssocRel                     elem_139682453254480
# 497         AssocRel                     elem_139682467580048
# 498         AssocRel                     elem_139682454978448
# 499         AssocRel                     elem_139682467402256
# 750         AssocRel                     elem_139682453252816
# 492         AssocRel                     elem_139682465716176
# 481         AssocRel                     elem_139682467580048
# 480         AssocRel                     elem_139682453247120
# 479         AssocRel                     elem_139682468739152
# 460         AssocRel                     elem_139682453247120
# 461         AssocRel                     elem_139682455130192
# 462         AssocRel                     elem_139682453246416
# 463         AssocRel                     elem_139682454976784
# 464         AssocRel                     elem_139682467223760
# 465         AssocRel                     elem_139682467580048
# 466         AssocRel                     elem_139682467402256
# 467         AssocRel                     elem_139682465716176
# 468         AssocRel                     elem_139682453254480
# 469         AssocRel                     elem_139682467580048
# 470         AssocRel                     elem_139682453252752
# 471         AssocRel                     elem_139682465984400
# 472         AssocRel                     elem_139682453246416
# 473         AssocRel                     elem_139682453246416
# 474         AssocRel                     elem_139682467066960
# 475         AssocRel                     elem_139682467402256
# 476         AssocRel                     elem_139682453248016
# 477         AssocRel                     elem_139682454978448
# 478         AssocRel                     elem_139682467402256
# 501         AssocRel                     elem_139682454964944
# 749         AssocRel                     elem_139682465716176
# 503         AssocRel                     elem_139682453244048
# 504         AssocRel                     elem_139682453253200
# 529         AssocRel                     elem_139682454976784
# 530         AssocRel                     elem_139682467580048
# 531         AssocRel                     elem_139682467408848
# 532         AssocRel                     elem_139682453252752
# 533         AssocRel                     elem_139682453252816
# 534         AssocRel                     elem_139682453248272
# 535         AssocRel                     elem_139682454964944
# 536         AssocRel                     elem_139682467402256
# 537         AssocRel                     elem_139682455130192
# 538         AssocRel                     elem_139682453246416
# 746         AssocRel                     elem_139682453244048
# 540         AssocRel                     elem_139682465716176
# 541         AssocRel                     elem_139682453252752
# 542         AssocRel                     elem_139682453253200
# 543         AssocRel                     elem_139682453252816
# 544         AssocRel                     elem_139682467223760
# 545         AssocRel                     elem_139682465984400
# 546         AssocRel                     elem_139682454968848
# 547         AssocRel                     elem_139682467580048
# 528         AssocRel                     elem_139682454978448
# 459         AssocRel                     elem_139682453246416
# 527         AssocRel                     elem_139682453252752
# 525         AssocRel                     elem_139682453254480
# 505         AssocRel                     elem_139682453246416
# 506         AssocRel                     elem_139682454976784
# 507         AssocRel                     elem_139682468739152
# 748         AssocRel                     elem_139682454964944
# 509         AssocRel                     elem_139682453252752
# 510         AssocRel                     elem_139682455132112
# 512         AssocRel                     elem_139682453248272
# 513         AssocRel                     elem_139682453248016
# 514         AssocRel                     elem_139682454978384
# 515         AssocRel                     elem_139682467223760
# 516         AssocRel                     elem_139682468739152
# 517         AssocRel                     elem_139682453247120
# 518         AssocRel                     elem_139682454968848
# 519         AssocRel                     elem_139682453248272
# 520         AssocRel                     elem_139682454976784
# 521         AssocRel                     elem_139682454978384
# 522         AssocRel                     elem_139682454978384
# 523         AssocRel                     elem_139682454978448
# 524         AssocRel                     elem_139682465716176
# 526         AssocRel                     elem_139682467223760
# 458         AssocRel                     elem_139682467588752
# 457         AssocRel                     elem_139682455132112
# 456         AssocRel                     elem_139682453246288
# 391         AssocRel                     elem_139682453244048
# 392         AssocRel                     elem_139682465984400
# 786         AssocRel                                     None
# 394         AssocRel                     elem_139682453248272
# 395         AssocRel                     elem_139682467066960
# 757         AssocRel                     elem_139682455132112
# 756         AssocRel                     elem_139682467588752
# 398         AssocRel                     elem_139682467402256
# 399         AssocRel                     elem_139682467066960
# 400         AssocRel                     elem_139682453252752
# 401         AssocRel                     elem_139682454978384
# 402         AssocRel                     elem_139682455132112
# 403         AssocRel                     elem_139682453246288
# 404         AssocRel                     elem_139682467066960
# 755         AssocRel                     elem_139682453244048
# 406         AssocRel                     elem_139682454978384
# 407         AssocRel                     elem_139682467588752
# 754         AssocRel                     elem_139682453252752
# 409         AssocRel                     elem_139682453248272
# 390         AssocRel                     elem_139682467399824
# 410         AssocRel                     elem_139682453244048
# 389         AssocRel                     elem_139682455132112
# 387         AssocRel                     elem_139682453252816
# 368         AssocRel                     elem_139682453247120
# 369         AssocRel                     elem_139682467588752
# 370         AssocRel                     elem_139682465984400
# 371         AssocRel                     elem_139682465984400
# 372         AssocRel                     elem_139682454964944
# 373         AssocRel                     elem_139682467588752
# 760         AssocRel                     elem_139682453248016
# 375         AssocRel                     elem_139682467399824
# 376         AssocRel                     elem_139682467408848
# 759         AssocRel                     elem_139682467399824
# 378         AssocRel                     elem_139682467402256
# 379         AssocRel                     elem_139682453248016
# 380         AssocRel                     elem_139682453247120
# 381         AssocRel                     elem_139682453246288
# 382         AssocRel                     elem_139682453247120
# 383         AssocRel                     elem_139682465716176
# 384         AssocRel                     elem_139682467066960
# 385         AssocRel                     elem_139682453248016
# 758         AssocRel                     elem_139682467588752
# 388         AssocRel                     elem_139682455130192
# 745         AssocRel                     elem_139682453252752
# 411         AssocRel                     elem_139682465984400
# 413         AssocRel                     elem_139682454978448
# 437         AssocRel                     elem_139682467066960
# 438         AssocRel                     elem_139682453246288
# 439         AssocRel                     elem_139682467399824
# 440         AssocRel                     elem_139682454968848
# 441         AssocRel                     elem_139682467223760
# 442         AssocRel                     elem_139682453253200
# 753         AssocRel                     elem_139682468739152
# 444         AssocRel                     elem_139682455130192
# 445         AssocRel                     elem_139682453247120
# 446         AssocRel                     elem_139682454964944
# 447         AssocRel                     elem_139682454968848
# 448         AssocRel                     elem_139682453246416
# 449         AssocRel                     elem_139682453248016
# 450         AssocRel                     elem_139682465716176
# 752         AssocRel                     elem_139682454964944
# 452         AssocRel                     elem_139682455132112
# 453         AssocRel                     elem_139682453246416
# 454         AssocRel                     elem_139682467066960
# 455         AssocRel                     elem_139682455130192
# 436         AssocRel                     elem_139682453252752
# 412         AssocRel                     elem_139682454968848
# 435         AssocRel                     elem_139682454968848
# 433         AssocRel                     elem_139682453252752
# 414         AssocRel                     elem_139682453248016
# 415         AssocRel                     elem_139682455130192
# 416         AssocRel                     elem_139682453253200
# 417         AssocRel                     elem_139682467408848
# 418         AssocRel                     elem_139682453248016
# 419         AssocRel                     elem_139682467399824
# 420         AssocRel                     elem_139682467402256
# 421         AssocRel                     elem_139682465716176
# 422         AssocRel                     elem_139682467066960
# 423         AssocRel                     elem_139682455130192
# 424         AssocRel                     elem_139682453248272
# 425         AssocRel                     elem_139682468739152
# 426         AssocRel                     elem_139682453247120
# 427         AssocRel                     elem_139682467588752
# 428         AssocRel                     elem_139682453254480
# 429         AssocRel                     elem_139682465716176
# 430         AssocRel                     elem_139682467580048
# 431         AssocRel                     elem_139682468739152
# 432         AssocRel                     elem_139682467223760
# 434         AssocRel                     elem_139682455130192
# 367         AssocRel                     elem_139682454976784
# 744         AssocRel                     elem_139682453253200
# 551         AssocRel                     elem_139682468739152
# 667         AssocRel                     elem_139682455130192
# 668         AssocRel                     elem_139682453248016
# 669         AssocRel                     elem_139682453248016
# 670         AssocRel                     elem_139682454976784
# 671         AssocRel                     elem_139682454978448
# 672         AssocRel                     elem_139682467399824
# 673         AssocRel                     elem_139682454976784
# 674         AssocRel                     elem_139682454978384
# 666         AssocRel                     elem_139682465716176
# 675         AssocRel                     elem_139682454968848
# 677         AssocRel                     elem_139682468739152
# 678         AssocRel                     elem_139682455132112
# 679         AssocRel                     elem_139682453246288
# 680         AssocRel                     elem_139682453247120
# 681         AssocRel                     elem_139682453253200
# 682         AssocRel                     elem_139682467402256
# 683         AssocRel                     elem_139682465984400
# 684         AssocRel                     elem_139682465716176
# 676         AssocRel                     elem_139682453248272
# 665         AssocRel                     elem_139682453248016
# 664         AssocRel                     elem_139682455132112
# 663         AssocRel                     elem_139682453248272
# 644         AssocRel                     elem_139682467399824
# 645         AssocRel                     elem_139682467588752
# 646         AssocRel                     elem_139682467588752
# 647         AssocRel                     elem_139682467223760
# 648         AssocRel                     elem_139682454976784
# 649         AssocRel                     elem_139682453252752
# 650         AssocRel                     elem_139682453252816
# 651         AssocRel                     elem_139682454978448
# 652         AssocRel                     elem_139682455130192
# 653         AssocRel                     elem_139682453246416
# 654         AssocRel                     elem_139682455130192
# 655         AssocRel                     elem_139682467580048
# 656         AssocRel                     elem_139682467588752
# 657         AssocRel                     elem_139682454978448
# 658         AssocRel                     elem_139682465716176
# 659         AssocRel                     elem_139682468739152
# 660         AssocRel                     elem_139682467066960
# 738         AssocRel                     elem_139682453253200
# 662         AssocRel                     elem_139682453246288
# 685         AssocRel                     elem_139682454976784
# 686         AssocRel                     elem_139682453252816
# 687         AssocRel                     elem_139682465716176
# 688         AssocRel                     elem_139682454964944
# 712         AssocRel                     elem_139682467223760
# 713         AssocRel                     elem_139682454978384
# 714         AssocRel                     elem_139682467408848
# 715         AssocRel                     elem_139682465716176
# 716         AssocRel                     elem_139682468739152
# 717         AssocRel                     elem_139682467399824
# 718         AssocRel                     elem_139682467588752
# 719         AssocRel                     elem_139682454968848
# 720         AssocRel                     elem_139682453247120
# 721         AssocRel                     elem_139682453252752
# 722         AssocRel                     elem_139682453246416
# 723         AssocRel                     elem_139682454978448
# 724         AssocRel                     elem_139682454978384
# 725         AssocRel                     elem_139682453246288
# 726         AssocRel                     elem_139682467223760
# 727         AssocRel                     elem_139682455132112
# 728         AssocRel                     elem_139682454978448
# 729         AssocRel                     elem_139682453252816
# 730         AssocRel                     elem_139682453254480
# 711         AssocRel                     elem_139682467066960
# 740         AssocRel                     elem_139682453248272
# 733         AssocRel                     elem_139682454978448
# 708         AssocRel                     elem_139682465984400
# 737         AssocRel                     elem_139682453252752
# 690         AssocRel                     elem_139682453244048
# 691         AssocRel                     elem_139682453254480
# 692         AssocRel                     elem_139682467402256
# 693         AssocRel                     elem_139682467399824
# 694         AssocRel                     elem_139682453248016
# 695         AssocRel                     elem_139682454968848
# 736         AssocRel                     elem_139682467408848
# 697         AssocRel                     elem_139682454968848
# 698         AssocRel                     elem_139682453246288
# 699         AssocRel                     elem_139682467408848
# 700         AssocRel                     elem_139682453244048
# 735         AssocRel                     elem_139682454978448
# 702         AssocRel                     elem_139682453253200
# 703         AssocRel                     elem_139682453246416
# 704         AssocRel                     elem_139682455132112
# 705         AssocRel                     elem_139682467588752
# 706         AssocRel                     elem_139682453247120
# 734         AssocRel                     elem_139682467580048
# 709         AssocRel                     elem_139682467399824
# 642         AssocRel                     elem_139682467580048
# 641         AssocRel                     elem_139682467402256
# 640         AssocRel                     elem_139682453253200
# 575         AssocRel                     elem_139682453252752
# 576         AssocRel                     elem_139682467408848
# 577         AssocRel                     elem_139682453248272
# 578         AssocRel                     elem_139682453246288
# 579         AssocRel                     elem_139682455130192
# 580         AssocRel                     elem_139682467580048
# 581         AssocRel                     elem_139682453246416
# 582         AssocRel                     elem_139682467588752
# 583         AssocRel                     elem_139682467580048
# 584         AssocRel                     elem_139682455130192
# 585         AssocRel                     elem_139682453252816
# 586         AssocRel                     elem_139682453244048
# 587         AssocRel                     elem_139682453246288
# 588         AssocRel                     elem_139682465984400
# 589         AssocRel                     elem_139682454964944
# 590         AssocRel                     elem_139682467408848
# 591         AssocRel                     elem_139682468739152
# 592         AssocRel                     elem_139682454978384
# 593         AssocRel                     elem_139682453254480
# 574         AssocRel                     elem_139682468739152
# 594         AssocRel                     elem_139682453244048
# 573         AssocRel                     elem_139682453253200
# 571         AssocRel                     elem_139682453244048
# 552         AssocRel                     elem_139682467402256
# 553         AssocRel                     elem_139682467399824
# 554         AssocRel                     elem_139682453247120
# 555         AssocRel                     elem_139682467223760
# 556         AssocRel                     elem_139682467580048
# 557         AssocRel                     elem_139682455130192
# 558         AssocRel                     elem_139682467408848
# 559         AssocRel                     elem_139682453252816
# 560         AssocRel                     elem_139682465716176
# 561         AssocRel                     elem_139682465984400
# 562         AssocRel                     elem_139682453248272
# 563         AssocRel                     elem_139682453248016
# 564         AssocRel                     elem_139682467408848
# 565         AssocRel                     elem_139682454976784
# 566         AssocRel                     elem_139682468739152
# 567         AssocRel                     elem_139682465716176
# 568         AssocRel                     elem_139682454978384
# 569         AssocRel                     elem_139682467066960
# 570         AssocRel                     elem_139682467408848
# 572         AssocRel                     elem_139682467066960
# 550         AssocRel                     elem_139682454968848
# 595         AssocRel                     elem_139682454968848
# 597         AssocRel                     elem_139682465716176
# 621         AssocRel                     elem_139682453252816
# 622         AssocRel                     elem_139682453248016
# 623         AssocRel                     elem_139682453246416
# 624         AssocRel                     elem_139682453248272
# 625         AssocRel                     elem_139682453244048
# 626         AssocRel                     elem_139682454978448
# 627         AssocRel                     elem_139682453244048
# 628         AssocRel                     elem_139682454978448
# 629         AssocRel                     elem_139682467408848
# 741         AssocRel                     elem_139682467580048
# 631         AssocRel                     elem_139682467066960
# 632         AssocRel                     elem_139682453252752
# 633         AssocRel                     elem_139682467066960
# 634         AssocRel                     elem_139682453246416
# 635         AssocRel                     elem_139682455130192
# 636         AssocRel                     elem_139682467408848
# 637         AssocRel                     elem_139682467588752
# 638         AssocRel                     elem_139682453252816
# 639         AssocRel                     elem_139682467399824
# 620         AssocRel                     elem_139682467399824
# 596         AssocRel                     elem_139682453254480
# 619         AssocRel                     elem_139682454978384
# 617         AssocRel                     elem_139682453246416
# 598         AssocRel                     elem_139682455130192
# 599         AssocRel                     elem_139682467223760
# 600         AssocRel                     elem_139682468739152
# 601         AssocRel                     elem_139682453254480
# 743         AssocRel                     elem_139682465984400
# 603         AssocRel                     elem_139682454964944
# 604         AssocRel                     elem_139682453252816
# 605         AssocRel                     elem_139682453247120
# 606         AssocRel                     elem_139682455132112
# 607         AssocRel                     elem_139682455132112
# 608         AssocRel                     elem_139682467066960
# 609         AssocRel                     elem_139682453246288
# 610         AssocRel                     elem_139682455130192
# 742         AssocRel                     elem_139682455132112
# 612         AssocRel                     elem_139682453247120
# 613         AssocRel                     elem_139682454976784
# 614         AssocRel                     elem_139682467223760
# 615         AssocRel                     elem_139682455130192
# 616         AssocRel                     elem_139682454978384
# 618         AssocRel                     elem_139682453248272
# 731         AssocRel                     elem_139682467408848
# 366         AssocRel                     elem_139682453247120
# 761         AssocRel                     elem_139682467399824
# 116         AssocRel                     elem_139682453246288
# 117         AssocRel                     elem_139682467399824
# 118         AssocRel                     elem_139682454968848
# 119         AssocRel                     elem_139682454968848
# 120         AssocRel                     elem_139682455130192
# 121         AssocRel                     elem_139682467066960
# 781         AssocRel                     elem_139682453248272
# 123         AssocRel                     elem_139682453252816
# 115         AssocRel                     elem_139682454976784
# 124         AssocRel                     elem_139682453248016
# 126         AssocRel                     elem_139682453248272
# 127         AssocRel                     elem_139682453254480
# 128         AssocRel                     elem_139682453254480
# 129         AssocRel                     elem_139682467408848
# 130         AssocRel                     elem_139682467580048
# 131         AssocRel                     elem_139682467580048
# 132         AssocRel                     elem_139682453248272
# 133         AssocRel                     elem_139682465984400
# 125         AssocRel                     elem_139682465716176
# 114         AssocRel                     elem_139682454978384
# 113         AssocRel                     elem_139682453248272
# 112         AssocRel                     elem_139682454964944
# 93          AssocRel                     elem_139682453244048
# 94          AssocRel                     elem_139682467588752
# 95          AssocRel                     elem_139682468739152
# 96          AssocRel                     elem_139682454978448
# 97          AssocRel                     elem_139682453246288
# 98          AssocRel                     elem_139682454964944
# 99          AssocRel                     elem_139682454978384
# 100         AssocRel                     elem_139682455132112
# 101         AssocRel                     elem_139682467580048
# 102         AssocRel                     elem_139682453248016
# 103         AssocRel                     elem_139682454968848
# 104         AssocRel                     elem_139682454978384
# 105         AssocRel                     elem_139682467399824
# 106         AssocRel                     elem_139682467399824
# 107         AssocRel                     elem_139682465984400
# 108         AssocRel                     elem_139682453244048
# 109         AssocRel                     elem_139682453253200
# 110         AssocRel                     elem_139682453252752
# 111         AssocRel                     elem_139682453252752
# 134         AssocRel                     elem_139682465984400
# 135         AssocRel                     elem_139682467402256
# 136         AssocRel                     elem_139682453253200
# 137         AssocRel                     elem_139682454976784
# 162         AssocRel                     elem_139682467223760
# 163         AssocRel                     elem_139682465984400
# 164         AssocRel                     elem_139682455130192
# 778         AssocRel                     elem_139682453246416
# 166         AssocRel                     elem_139682468739152
# 167         AssocRel                     elem_139682467588752
# 168         AssocRel                     elem_139682468739152
# 169         AssocRel                     elem_139682453244048
# 170         AssocRel                     elem_139682468739152
# 171         AssocRel                     elem_139682453247120
# 172         AssocRel                     elem_139682454976784
# 173         AssocRel                     elem_139682454964944
# 174         AssocRel                     elem_139682454976784
# 175         AssocRel                     elem_139682467399824
# 176         AssocRel                     elem_139682453246288
# 177         AssocRel                     elem_139682467399824
# 777         AssocRel                     elem_139682453246416
# 179         AssocRel                     elem_139682453248272
# 180         AssocRel                     elem_139682453246416
# 161         AssocRel                     elem_139682468739152
# 92          AssocRel                     elem_139682467066960
# 160         AssocRel                     elem_139682454978448
# 158         AssocRel                     elem_139682453254480
# 138         AssocRel                     elem_139682454978448
# 140         AssocRel                     elem_139682467066960
# 141         AssocRel                     elem_139682465984400
# 142         AssocRel                     elem_139682455132112
# 143         AssocRel                     elem_139682453244048
# 144         AssocRel                     elem_139682467402256
# 145         AssocRel                     elem_139682453254480
# 146         AssocRel                     elem_139682453248272
# 147         AssocRel                     elem_139682453252752
# 148         AssocRel                     elem_139682454964944
# 149         AssocRel                     elem_139682467399824
# 779         AssocRel                     elem_139682453248016
# 151         AssocRel                     elem_139682453244048
# 152         AssocRel                     elem_139682453247120
# 153         AssocRel                     elem_139682453254480
# 154         AssocRel                     elem_139682465716176
# 155         AssocRel                     elem_139682467399824
# 156         AssocRel                     elem_139682453246288
# 157         AssocRel                     elem_139682453246288
# 159         AssocRel                     elem_139682467223760
# 91          AssocRel                     elem_139682455132112
# 90          AssocRel                     elem_139682467580048
# 89          AssocRel                     elem_139682453252816
# 24          AssocRel                     elem_139682467588752
# 25          AssocRel                     elem_139682468739152
# 26          AssocRel                     elem_139682453246416
# 27          AssocRel                     elem_139682467402256
# 28          AssocRel                     elem_139682468739152
# 29          AssocRel                     elem_139682453253200
# 30          AssocRel                     elem_139682455130192
# 31          AssocRel                     elem_139682467580048
# 32          AssocRel                     elem_139682454964944
# 33          AssocRel                     elem_139682467223760
# 34          AssocRel                     elem_139682453247120
# 35          AssocRel                     elem_139682467399824
# 36          AssocRel                     elem_139682453252816
# 37          AssocRel                     elem_139682453247120
# 38          AssocRel                     elem_139682467066960
# 39          AssocRel                     elem_139682465716176
# 40          AssocRel                     elem_139682453244048
# 41          AssocRel                     elem_139682453253200
# 42          AssocRel                     elem_139682455130192
# 23          AssocRel                     elem_139682453248016
# 43          AssocRel                     elem_139682468739152
# 22          AssocRel                     elem_139682454968848
# 20          AssocRel                     elem_139682467399824
# 1           AssocRel                     elem_139682467223760
# 2           AssocRel                     elem_139682454968848
# 3           AssocRel                     elem_139682453252752
# 4           AssocRel                     elem_139682455132112
# 5           AssocRel                     elem_139682453254480
# 6           AssocRel                     elem_139682453246288
# 7           AssocRel                     elem_139682453252816
# 8           AssocRel                     elem_139682453247120
# 9           AssocRel                     elem_139682454976784
# 10          AssocRel                     elem_139682454968848
# 11          AssocRel                     elem_139682454978448
# 12          AssocRel                     elem_139682467399824
# 13          AssocRel                     elem_139682467580048
# 14          AssocRel                     elem_139682467402256
# 15          AssocRel                     elem_139682467223760
# 16          AssocRel                     elem_139682453252752
# 17          AssocRel                     elem_139682454978448
# 18          AssocRel                     elem_139682467408848
# 19          AssocRel                     elem_139682453254480
# 21          AssocRel                     elem_139682465984400
# 181         AssocRel                     elem_139682453254480
# 44          AssocRel                     elem_139682467408848
# 46          AssocRel                     elem_139682453252816
# 70          AssocRel                     elem_139682467402256
# 71          AssocRel                     elem_139682453246416
# 72          AssocRel                     elem_139682454976784
# 73          AssocRel                     elem_139682454978448
# 74          AssocRel                     elem_139682455132112
# 75          AssocRel                     elem_139682465716176
# 76          AssocRel                     elem_139682467402256
# 782         AssocRel                     elem_139682453244048
# 78          AssocRel                     elem_139682467580048
# 79          AssocRel                     elem_139682453248016
# 80          AssocRel                     elem_139682453253200
# 81          AssocRel                     elem_139682453246416
# 82          AssocRel                     elem_139682454978448
# 83          AssocRel                     elem_139682454964944
# 84          AssocRel                     elem_139682467223760
# 85          AssocRel                     elem_139682467402256
# 86          AssocRel                     elem_139682467588752
# 87          AssocRel                     elem_139682453252752
# 88          AssocRel                     elem_139682467066960
# 69          AssocRel                     elem_139682455132112
# 45          AssocRel                     elem_139682454964944
# 68          AssocRel                     elem_139682453248272
# 66          AssocRel                     elem_139682467588752
# 47          AssocRel                     elem_139682467408848
# 48          AssocRel                     elem_139682454978384
# 49          AssocRel                     elem_139682453253200
# 784         AssocRel                     elem_139682468739152
# 51          AssocRel                     elem_139682453244048
# 52          AssocRel                     elem_139682455132112
# 53          AssocRel                     elem_139682453254480
# 54          AssocRel                     elem_139682454968848
# 55          AssocRel                     elem_139682467408848
# 56          AssocRel                     elem_139682453244048
# 57          AssocRel                     elem_139682453248272
# 58          AssocRel                     elem_139682454968848
# 783         AssocRel                     elem_139682465984400
# 60          AssocRel                     elem_139682467408848
# 61          AssocRel                     elem_139682467223760
# 62          AssocRel                     elem_139682467223760
# 63          AssocRel                     elem_139682467588752
# 64          AssocRel                     elem_139682453254480
# 65          AssocRel                     elem_139682453253200
# 67          AssocRel                     elem_139682467066960
# 365         AssocRel                     elem_139682453246288
# 182         AssocRel                     elem_139682453248272
# 184         AssocRel                     elem_139682453253200
# 298         AssocRel                     elem_139682453248272
# 299         AssocRel                     elem_139682453253200
# 300         AssocRel                     elem_139682467066960
# 301         AssocRel                     elem_139682467408848
# 302         AssocRel                     elem_139682467408848
# 303         AssocRel                     elem_139682453244048
# 304         AssocRel                     elem_139682453253200
# 305         AssocRel                     elem_139682453252752
# 306         AssocRel                     elem_139682454964944
# 307         AssocRel                     elem_139682454978448
# 308         AssocRel                     elem_139682453246288
# 309         AssocRel                     elem_139682468739152
# 311         AssocRel                     elem_139682453252816
# 312         AssocRel                     elem_139682453247120
# 766         AssocRel                     elem_139682467408848
# 314         AssocRel                     elem_139682465984400
# 315         AssocRel                     elem_139682467580048
# 316         AssocRel                     elem_139682454976784
# 317         AssocRel                     elem_139682467402256
# 297         AssocRel                     elem_139682455130192
# 318         AssocRel                     elem_139682467408848
# 296         AssocRel                     elem_139682467588752
# 294         AssocRel                     elem_139682453253200
# 275         AssocRel                     elem_139682467223760
# 276         AssocRel                     elem_139682454978384
# 277         AssocRel                     elem_139682453252816
# 278         AssocRel                     elem_139682453246288
# 279         AssocRel                     elem_139682453247120
# 280         AssocRel                     elem_139682453254480
# 281         AssocRel                     elem_139682467399824
# 282         AssocRel                     elem_139682454968848
# 283         AssocRel                     elem_139682454968848
# 284         AssocRel                     elem_139682455132112
# 285         AssocRel                     elem_139682467399824
# 286         AssocRel                     elem_139682465984400
# 287         AssocRel                     elem_139682454964944
# 288         AssocRel                     elem_139682453252816
# 768         AssocRel                     elem_139682467580048
# 290         AssocRel                     elem_139682467402256
# 291         AssocRel                     elem_139682467402256
# 292         AssocRel                     elem_139682453246288
# 293         AssocRel                     elem_139682453246416
# 295         AssocRel                     elem_139682453252816
# 274         AssocRel                     elem_139682467223760
# 319         AssocRel                     elem_139682468739152
# 321         AssocRel                     elem_139682454964944
# 345         AssocRel                     elem_139682455132112
# 346         AssocRel                     elem_139682453252752
# 347         AssocRel                     elem_139682455132112
# 348         AssocRel                     elem_139682467408848
# 349         AssocRel                     elem_139682467588752
# 350         AssocRel                     elem_139682467066960
# 351         AssocRel                     elem_139682465984400
# 352         AssocRel                     elem_139682467408848
# 764         AssocRel                     elem_139682454976784
# 354         AssocRel                     elem_139682453252816
# 763         AssocRel                     elem_139682467402256
# 356         AssocRel                     elem_139682467066960
# 357         AssocRel                     elem_139682467402256
# 358         AssocRel                     elem_139682453244048
# 762         AssocRel                     elem_139682465984400
# 360         AssocRel                     elem_139682453248016
# 361         AssocRel                     elem_139682467580048
# 362         AssocRel                     elem_139682468739152
# 363         AssocRel                     elem_139682465716176
# 344         AssocRel                     elem_139682467580048
# 320         AssocRel                     elem_139682453246416
# 343         AssocRel                     elem_139682465984400
# 341         AssocRel                     elem_139682465716176
# 322         AssocRel                     elem_139682454976784
# 323         AssocRel                     elem_139682453248272
# 324         AssocRel                     elem_139682453248272
# 325         AssocRel                     elem_139682454976784
# 326         AssocRel                     elem_139682455132112
# 327         AssocRel                     elem_139682455130192
# 328         AssocRel                     elem_139682453246288
# 329         AssocRel                     elem_139682453252752
# 330         AssocRel                     elem_139682467580048
# 331         AssocRel                     elem_139682467408848
# 332         AssocRel                     elem_139682465716176
# 333         AssocRel                     elem_139682453246416
# 334         AssocRel                     elem_139682454964944
# 335         AssocRel                     elem_139682454978384
# 336         AssocRel                     elem_139682453252816
# 765         AssocRel                     elem_139682454976784
# 338         AssocRel                     elem_139682453252816
# 339         AssocRel                     elem_139682453252816
# 340         AssocRel                     elem_139682453246288
# 342         AssocRel                     elem_139682467588752
# 183         AssocRel                     elem_139682454964944
# 273         AssocRel                     elem_139682453252752
# 271         AssocRel                     elem_139682454978448
# 208         AssocRel                     elem_139682467580048
# 209         AssocRel                     elem_139682453253200
# 210         AssocRel                     elem_139682453253200
# 211         AssocRel                     elem_139682454978384
# 212         AssocRel                     elem_139682453254480
# 213         AssocRel                     elem_139682468739152
# 774         AssocRel                     elem_139682453252816
# 215         AssocRel                     elem_139682453248016
# 207         AssocRel                     elem_139682453248016
# 216         AssocRel                     elem_139682453248016
# 218         AssocRel                     elem_139682465716176
# 219         AssocRel                     elem_139682454978384
# 220         AssocRel                     elem_139682454976784
# 221         AssocRel                     elem_139682454978384
# 222         AssocRel                     elem_139682454978448
# 223         AssocRel                     elem_139682454968848
# 224         AssocRel                     elem_139682467066960
# 225         AssocRel                     elem_139682453247120
# 217         AssocRel                     elem_139682465984400
# 206         AssocRel                     elem_139682453253200
# 205         AssocRel                     elem_139682465984400
# 204         AssocRel                     elem_139682453252752
# 185         AssocRel                     elem_139682454978384
# 186         AssocRel                     elem_139682455130192
# 187         AssocRel                     elem_139682453247120
# 776         AssocRel                     elem_139682467066960
# 189         AssocRel                     elem_139682467223760
# 775         AssocRel                     elem_139682467402256
# 191         AssocRel                     elem_139682454964944
# 192         AssocRel                     elem_139682453247120
# 193         AssocRel                     elem_139682454978448
# 194         AssocRel                     elem_139682453247120
# 195         AssocRel                     elem_139682454964944
# 196         AssocRel                     elem_139682454968848
# 197         AssocRel                     elem_139682453254480
# 198         AssocRel                     elem_139682454964944
# 199         AssocRel                     elem_139682454978384
# 200         AssocRel                     elem_139682453254480
# 201         AssocRel                     elem_139682453248016
# 202         AssocRel                     elem_139682453254480
# 203         AssocRel                     elem_139682455130192
# 226         AssocRel                     elem_139682465716176
# 272         AssocRel                     elem_139682467223760
# 227         AssocRel                     elem_139682467223760
# 229         AssocRel                     elem_139682454978448
# 251         AssocRel                     elem_139682453244048
# 252         AssocRel                     elem_139682454976784
# 253         AssocRel                     elem_139682467402256
# 254         AssocRel                     elem_139682453253200
# 255         AssocRel                     elem_139682455130192
# 773         AssocRel                     elem_139682455132112
# 772         AssocRel                     elem_139682467588752
# 258         AssocRel                     elem_139682454976784
# 259         AssocRel                     elem_139682454978384
# 250         AssocRel                     elem_139682453246288
# 260         AssocRel                     elem_139682467588752
# 771         AssocRel                     elem_139682453254480
# 263         AssocRel                     elem_139682453244048
# 264         AssocRel                     elem_139682467588752
# 265         AssocRel                     elem_139682454978384
# 266         AssocRel                     elem_139682453244048
# 267         AssocRel                     elem_139682453253200
# 268         AssocRel                     elem_139682453246288
# 770         AssocRel                     elem_139682454978384
# 769         AssocRel                     elem_139682454968848
# 261         AssocRel                     elem_139682453248016
# 228         AssocRel                     elem_139682467223760
# 249         AssocRel                     elem_139682454964944
# 247         AssocRel                     elem_139682467399824
# 230         AssocRel                     elem_139682454978384
# 231         AssocRel                     elem_139682453252752
# 232         AssocRel                     elem_139682453248016
# 233         AssocRel                     elem_139682453248272
# 234         AssocRel                     elem_139682453253200
# 235         AssocRel                     elem_139682454978448
# 248         AssocRel                     elem_139682455132112
# 237         AssocRel                     elem_139682454964944
# 236         AssocRel                     elem_139682453252816
# 239         AssocRel                     elem_139682454976784
# 240         AssocRel                     elem_139682455132112
# 241         AssocRel                     elem_139682453246416
# 242         AssocRel                     elem_139682453246416
# 243         AssocRel                     elem_139682453248016
# 244         AssocRel                     elem_139682453254480
# 245         AssocRel                     elem_139682467066960
# 246         AssocRel                     elem_139682467223760
# 238         AssocRel                     elem_139682465716176
# 732         AssocRel                     elem_139682454968848
# 747  AttrIntExistRel                     elem_139682465984400
# 767  AttrIntExistRel                     elem_139682454968848
# 780  AttrIntExistRel                     elem_139682453254480
# 787  AttrIntExistRel                                     None
# 500  AttrIntExistRel                     elem_139682453246288
# 337  AttrIntExistRel                     elem_139682454976784
# 353  AttrIntExistRel                     elem_139682467399824
# ...
# 111                elem_139682468739152
# 134                elem_139682454978384
# 135                elem_139682467588752
# 136                elem_139682453247120
# 137                elem_139682467223760
# 162                elem_139682465716176
# 163                elem_139682453247120
# 164                elem_139682453247120
# 778                elem_139682453246288
# 166                elem_139682453253200
# 167                elem_139682453253200
# 168                elem_139682455132112
# 169                elem_139682454978448
# 170                elem_139682455130192
# 171                elem_139682453254480
# 172                elem_139682468739152
# 173                elem_139682453252752
# 174                elem_139682467399824
# 175                elem_139682453252752
# 176                elem_139682467066960
# 177                elem_139682454968848
# 777                elem_139682453244048
# 179                elem_139682467580048
# 180                elem_139682455132112
# 161                elem_139682453248016
# 92                 elem_139682467402256
# 160                elem_139682453253200
# 158                elem_139682455130192
# 138                elem_139682453248272
# 140                elem_139682465984400
# 141                elem_139682454978448
# 142                elem_139682454978448
# 143                elem_139682454976784
# 144                elem_139682454968848
# 145                elem_139682467402256
# 146                elem_139682467066960
# 147                elem_139682465716176
# 148                elem_139682453254480
# 149                elem_139682454964944
# 779                elem_139682455132112
# 151                elem_139682467399824
# 152                elem_139682467402256
# 153                elem_139682467223760
# 154                elem_139682455130192
# 155                elem_139682467066960
# 156                elem_139682454976784
# 157                elem_139682453248272
# 159                elem_139682467402256
# 91                 elem_139682453248016
# 90                 elem_139682453252816
# 89                 elem_139682453252752
# 24                 elem_139682454976784
# 25                 elem_139682454968848
# 26                 elem_139682453253200
# 27                 elem_139682453248272
# 28                 elem_139682453247120
# 29                 elem_139682453248272
# 30                 elem_139682468739152
# 31                 elem_139682468739152
# 32                 elem_139682454976784
# 33                 elem_139682455132112
# 34                 elem_139682467588752
# 35                 elem_139682468739152
# 36                 elem_139682454976784
# 37                 elem_139682454978448
# 38                 elem_139682454968848
# 39                 elem_139682454978384
# 40                 elem_139682453244048
# 41                 elem_139682454968848
# 42                 elem_139682467223760
# 23                 elem_139682453252816
# 43                 elem_139682453246416
# 22                 elem_139682454964944
# 20                 elem_139682467223760
# 1                  elem_139682453244048
# 2                  elem_139682467588752
# 3                  elem_139682454964944
# 4                  elem_139682454964944
# 5                  elem_139682465984400
# 6                  elem_139682454968848
# 7                  elem_139682453253200
# 8                  elem_139682467408848
# 9                  elem_139682454964944
# 10                 elem_139682453246288
# 11                 elem_139682453247120
# 12                 elem_139682453246416
# 13                 elem_139682454978448
# 14                 elem_139682465984400
# 15                 elem_139682454968848
# 16                 elem_139682467408848
# 17                 elem_139682465984400
# 18                 elem_139682467588752
# 19                 elem_139682454964944
# 21                 elem_139682454964944
# 181                elem_139682454976784
# 44                 elem_139682454968848
# 46                 elem_139682465716176
# 70                 elem_139682454964944
# 71                 elem_139682454978448
# 72                 elem_139682467402256
# 73                 elem_139682468739152
# 74                 elem_139682453246288
# 75                 elem_139682465716176
# 76                 elem_139682453253200
# 782                elem_139682467223760
# 78                 elem_139682455130192
# 79                 elem_139682453253200
# 80                 elem_139682453253200
# 81                 elem_139682467399824
# 82                 elem_139682455132112
# 83                 elem_139682453248016
# 84                 elem_139682467588752
# 85                 elem_139682468739152
# 86                 elem_139682467399824
# 87                 elem_139682454976784
# 88                 elem_139682467066960
# 69                 elem_139682453247120
# 45                 elem_139682453253200
# 68                 elem_139682468739152
# 66                 elem_139682453254480
# 47                 elem_139682455130192
# 48                 elem_139682453252816
# 49                 elem_139682468739152
# 784                elem_139682467408848
# 51                 elem_139682454978384
# 52                 elem_139682468739152
# 53                 elem_139682453246288
# 54                 elem_139682467066960
# 55                 elem_139682467066960
# 56                 elem_139682453248272
# 57                 elem_139682454978448
# 58                 elem_139682465984400
# 783                elem_139682453253200
# 60                 elem_139682453254480
# 61                 elem_139682467408848
# 62                 elem_139682453246416
# 63                 elem_139682454978384
# 64                 elem_139682453252752
# 65                 elem_139682455132112
# 67                 elem_139682468739152
# 365                elem_139682453246288
# 182                elem_139682455132112
# 184                elem_139682467402256
# 298                elem_139682454976784
# 299                elem_139682454978384
# 300                elem_139682453252752
# 301                elem_139682453246416
# 302                elem_139682454964944
# 303                elem_139682467066960
# 304                elem_139682453246416
# 305                elem_139682453246416
# 306                elem_139682454968848
# 307                elem_139682454976784
# 308                elem_139682467580048
# 309                elem_139682453252752
# 311                elem_139682453252816
# 312                elem_139682453248016
# 766                elem_139682455132112
# 314                elem_139682467580048
# 315                elem_139682453253200
# 316                elem_139682467588752
# 317                elem_139682467580048
# 297                elem_139682453246416
# 318                elem_139682467223760
# 296                elem_139682453244048
# 294                elem_139682467066960
# 275                elem_139682453248272
# 276                elem_139682453248016
# 277                elem_139682453248272
# 278                elem_139682454978448
# 279                elem_139682453248272
# 280                elem_139682455132112
# 281                elem_139682465716176
# 282                elem_139682454978384
# 283                elem_139682455130192
# 284                elem_139682467402256
# 285                elem_139682453246288
# 286                elem_139682465716176
# 287                elem_139682455132112
# 288                elem_139682467066960
# 768                elem_139682454968848
# 290                elem_139682454976784
# 291                elem_139682467066960
# 292                elem_139682454978384
# 293                elem_139682453254480
# 295                elem_139682467399824
# 274                elem_139682454978448
# 319                elem_139682454978448
# 321                elem_139682454964944
# 345                elem_139682453244048
# 346                elem_139682467223760
# 347                elem_139682467588752
# 348                elem_139682454978384
# 349                elem_139682453248016
# 350                elem_139682467580048
# 351                elem_139682453248272
# 352                elem_139682453252752
# 764                elem_139682453244048
# 354                elem_139682453248016
# 763                elem_139682455132112
# 356                elem_139682467399824
# 357                elem_139682454978448
# 358                elem_139682453253200
# 762                elem_139682455132112
# 360                elem_139682453248016
# 361                elem_139682453246288
# 362                elem_139682454976784
# 363                elem_139682467408848
# 344                elem_139682467066960
# 320                elem_139682467402256
# 343                elem_139682465984400
# 341                elem_139682454978448
# 322                elem_139682453253200
# 323                elem_139682453246416
# 324                elem_139682453244048
# 325                elem_139682453246288
# 326                elem_139682453254480
# 327                elem_139682454978384
# 328                elem_139682467402256
# 329                elem_139682467066960
# 330                elem_139682467223760
# 331                elem_139682465716176
# 332                elem_139682467402256
# 333                elem_139682467580048
# 334                elem_139682465984400
# 335                elem_139682453244048
# 336                elem_139682453246288
# 765                elem_139682455130192
# 338                elem_139682454978448
# 339                elem_139682453246416
# 340                elem_139682455132112
# 342                elem_139682467588752
# 183                elem_139682465716176
# 273                elem_139682453246288
# 271                elem_139682454978384
# 208                elem_139682465984400
# 209                elem_139682454976784
# 210                elem_139682453252752
# 211                elem_139682453254480
# 212                elem_139682453247120
# 213                elem_139682453244048
# 774                elem_139682465984400
# 215                elem_139682468739152
# 207                elem_139682465716176
# 216                elem_139682467402256
# 218                elem_139682454968848
# 219                elem_139682453246288
# 220                elem_139682453246416
# 221                elem_139682453253200
# 222                elem_139682467408848
# 223                elem_139682465716176
# 224                elem_139682453254480
# 225                elem_139682454976784
# 217                elem_139682467399824
# 206                elem_139682467223760
# 205                elem_139682467402256
# 204                elem_139682467402256
# 185                elem_139682455132112
# 186                elem_139682467399824
# 187                elem_139682454964944
# 776                elem_139682454978448
# 189                elem_139682453247120
# 775                elem_139682453252816
# 191                elem_139682467408848
# 192                elem_139682453252816
# 193                elem_139682454964944
# 194                elem_139682453252752
# 195                elem_139682454978384
# 196                elem_139682454978448
# 197                elem_139682453253200
# 198                elem_139682453246288
# 199                elem_139682467588752
# 200                elem_139682453248272
# 201                elem_139682467588752
# 202                elem_139682467399824
# 203                elem_139682453248272
# 226                elem_139682453252752
# 272                elem_139682453252816
# 227                elem_139682453254480
# 229                elem_139682453244048
# 251                elem_139682453252752
# 252                elem_139682454968848
# 253                elem_139682453247120
# 254                elem_139682454978448
# 255                elem_139682465984400
# 773                elem_139682454976784
# 772                elem_139682467408848
# 258                elem_139682467408848
# 259                elem_139682454968848
# 250                elem_139682467223760
# 260                elem_139682453247120
# 771                elem_139682468739152
# 263                elem_139682467408848
# 264                elem_139682453252816
# 265                elem_139682453248272
# 266                elem_139682467588752
# 267                elem_139682453244048
# 268                elem_139682465984400
# 770                elem_139682454978448
# 769                elem_139682453248016
# 261                elem_139682467223760
# 228                elem_139682453246288
# 249                elem_139682467580048
# 247                elem_139682453252816
# 230                elem_139682453252752
# 231                elem_139682454968848
# 232                elem_139682453247120
# 233                elem_139682453252816
# 234                elem_139682467408848
# 235                elem_139682453246288
# 248                elem_139682453246416
# 237                elem_139682453244048
# 236                elem_139682455130192
# 239                elem_139682453248016
# 240                elem_139682453248272
# 241                elem_139682454968848
# 242                elem_139682467223760
# 243                elem_139682453246416
# 244                elem_139682453252816
# 245                elem_139682453246416
# 246                elem_139682468739152
# 238                elem_139682467588752
# 732                elem_139682455132112
# 747                                None
# 767                                None
# 780                                None
# 787                                None
# 500                                None
# 337                                None
# 353                                None
# 270                                None
# 269                                None
# 214                                None
# 190                                None
# 397                                None
# 405                                None
# 443                                None
# 289                                None
# 150                                None
# 511                                None
# 310                                None
# 643                                None
# 548                                None
# 122                                None
# 701                                None
# 602                                None
# 689                                None
# 611                                None
# 630                                None
# 539                                None
# 661                                None
# 785                                None
# 262                   commons_SProperty
# 139                 infrastructure_Rule
# 256                 infrastructure_Rule
# 50               infrastructure_KeyPair
# 188                 infrastructure_Rule
# 178              infrastructure_VMImage
# 165                   commons_SProperty
# 257        application_ApplicationLayer
# 707                   commons_SProperty
# 374     concrete_ConcreteInfrastructure
# 355       application_SoftwareComponent
# 696                   commons_SProperty
# 739            concrete_RuntimeProvider
# 549                    concrete_Network
# 508     infrastructure_NetworkInterface
# 502                 infrastructure_Rule
# 313  infrastructure_InfrastructureLayer
# 451               commons_Configuration
# 487       infrastructure_VirtualMachine
# 396     infrastructure_AutoScalingGroup
# 386             concrete_VirtualMachine
# 377                   commons_SProperty
# 710        infrastructure_SecurityGroup
# 364                  commons_Deployment
# 359              infrastructure_Network
# 408                   commons_SProperty
# 393                    concrete_VMImage
# 59                                 None
# 77                                 None
