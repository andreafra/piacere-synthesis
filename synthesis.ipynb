# %%
from z3 import *

import yaml
import pandas as pd

from dataclasses import dataclass
from pprint import pprint
from typing import Optional
from itertools import product

pd.set_option('display.max_rows', None)

# %%
MM_FILE = './assets/metamodels/doml_meta_v2.0.yaml'

IM_FILE = './assets/doml/2.0/nginx-openstack_v2.0.yaml'
# IM_FILE = './assets/doml/2.0/nginx-openstack_v2.0_wrong_vm_iface.yaml'

UB_ELEMS = 0

# %%
with open(MM_FILE, 'r') as mm_file:
    mm = yaml.safe_load(mm_file)

with open(IM_FILE, 'r') as im_file:
    im = yaml.safe_load(im_file)

# %% [markdown]
# We need to create first the elements by parsing the metamodel

# %%
classes = { f'{cat_k}_{elem_k}' : elem_v
    for cat_k, cat_v in mm.items()
    for elem_k, elem_v in cat_v.items() 
}

def merge_superclass(elem):
    e_k, e_v = elem
    sc_k = e_v.get('superclass')
    sc_v = classes.get(sc_k)
    if not sc_k:
        e_v['associations'] = {f'{e_k}::{k}': v for k,v in e_v.get('associations',{}).items()}
        e_v['attributes'] = {f'{e_k}::{k}': v for k,v in e_v.get('attributes',{}).items()}
        return e_v
    else:
        e_v['associations'] = {f'{e_k}::{k}': v for k,v in e_v.get('associations',{}).items()} | sc_v.get('associations',{})
        e_v['attributes'] = {f'{e_k}::{k}': v for k,v in e_v.get('attributes',{}).items()} | sc_v.get('attributes',{})
        return e_v

# all the elements with all the inherited attributes and associations
merged_classes = { 
    k : merge_superclass((k,v))
    for k,v in classes.items()
}

# %%
@dataclass
class Class:
    name: str
    attributes: dict[str, dict]
    associations: dict[str, dict]
    ref: Optional[SortRef] = None

@dataclass
class Elem:
    id: str
    name: Optional[str]
    attributes: dict[str, dict]
    associations: dict[str, dict]
    eClass: Optional[Class] = None
    ref: Optional[SortRef] = None
    unbound: bool = False

@dataclass
class AssocRel:
    from_elem: Class
    to_elem: Class
    inverse_of: Optional[str]
    ref: Optional[FuncDeclRef] = None

@dataclass
class AttrRel:
    multiplicity: str
    type: str
    ref: Optional[FuncDeclRef] = None

# Convert ELEMS
CLASSES = {
    class_k : Class(
        class_k, 
        class_v.get('attributes', {}), 
        class_v.get('associations', {})
    )
    for class_k, class_v in merged_classes.items()
}

ELEMS = {
    elem_k : Elem(
        elem_v['id'],
        elem_v['name'],
        elem_v['attrs'],
        elem_v['assocs'],
        CLASSES[elem_v['class']],
    )
    for elem_k, elem_v in im.items()
}

# This also helps catching errors in class/assoc names
ASSOCS = {
    f'{assoc_k}' : AssocRel(class_v, CLASSES[assoc_v['class']], assoc_v.get('inverse_of', None))
    for class_k, class_v in CLASSES.items()
    for assoc_k, assoc_v in class_v.associations.items()
}

# Careful: I decided to default multiplicity to 0..1
ATTRS = {
    f'{attr_k}' : AttrRel(attr_v.get('multiplicity', '0..1'), attr_v['type'])
    for class_k, class_v in CLASSES.items()
    for attr_k, attr_v in class_v.attributes.items()
}

# %% [markdown]
# Visualization of all the Elems and Assocs

# %%
classes_df = pd.DataFrame.from_dict([
    {
        'name': name
    }
    for name, value in CLASSES.items()
])

classes_df
# Out:
#                                        name
# 0                       commons_DOMLElement
# 1                          commons_Property
# 2                         commons_IProperty
# 3                         commons_SProperty
# 4                         commons_FProperty
# 5                         commons_BProperty
# 6                     commons_Configuration
# 7                        commons_Deployment
# 8              application_ApplicationLayer
# 9          application_ApplicationComponent
# 10            application_SoftwareComponent
# 11                         application_SaaS
# 12            application_SoftwareInterface
# 13                         application_DBMS
# 14                     application_SaaSDBMS
# 15       infrastructure_InfrastructureLayer
# 16     infrastructure_InfrastructureElement
# 17             infrastructure_ComputingNode
# 18     infrastructure_PhysicalComputingNode
# 19            infrastructure_VirtualMachine
# 20                  infrastructure_Location
# 21                 infrastructure_Container
# 22    infrastructure_ComputingNodeGenerator
# 23                   infrastructure_VMImage
# 24            infrastructure_ContainerImage
# 25          infrastructure_AutoScalingGroup
# 26                   infrastructure_Storage
# 27        infrastructure_FunctionAsAService
# 28                   infrastructure_Network
# 29                    infrastructure_Subnet
# 30          infrastructure_NetworkInterface
# 31           infrastructure_InternetGateway
# 32            infrastructure_ComputingGroup
# 33             infrastructure_SecurityGroup
# 34                      infrastructure_Rule
# 35               infrastructure_Credentials
# 36                   infrastructure_KeyPair
# 37                  infrastructure_UserPass
# 38                 infrastructure_SwarmRole
# 39                     infrastructure_Swarm
# 40  infrastructure_ExtInfrastructureElement
# 41          concrete_ConcreteInfrastructure
# 42                 concrete_ConcreteElement
# 43                 concrete_RuntimeProvider
# 44                  concrete_VirtualMachine
# 45                         concrete_VMImage
# 46                  concrete_ContainerImage
# 47                         concrete_Network
# 48                         concrete_Storage
# 49              concrete_FunctionAsAService
# 50                  concrete_ComputingGroup

# %%
assoc_df = pd.DataFrame.from_dict([
    {
        'name': name,
        'from': value.from_elem.name,
        'to': value.to_elem.name,
        'inverse': value.inverse_of
    }
    for name, value in ASSOCS.items()
])

assoc_df[['from', 'name', 'to', 'inverse']]
# Out:
#                                   from  \
# 0              concrete_ComputingGroup
# 1                    commons_BProperty
# 2                commons_Configuration
# 3                   commons_Deployment
# 4                   commons_Deployment
# 5         application_ApplicationLayer
# 6                     application_DBMS
# 7                     application_DBMS
# 8                 application_SaaSDBMS
# 9   infrastructure_InfrastructureLayer
# 10  infrastructure_InfrastructureLayer
# 11  infrastructure_InfrastructureLayer
# 12  infrastructure_InfrastructureLayer
# 13  infrastructure_InfrastructureLayer
# 14  infrastructure_InfrastructureLayer
# 15  infrastructure_InfrastructureLayer
# 16  infrastructure_InfrastructureLayer
# 17            infrastructure_Container
# 18            infrastructure_Container
# 19            infrastructure_Container
# 20            infrastructure_Container
# 21       infrastructure_VirtualMachine
# 22            infrastructure_Container
# 23            infrastructure_Container
# 24              infrastructure_VMImage
# 25       infrastructure_ContainerImage
# 26     infrastructure_AutoScalingGroup
# 27     infrastructure_AutoScalingGroup
# 28     infrastructure_AutoScalingGroup
# 29     infrastructure_AutoScalingGroup
# 30              infrastructure_Storage
# 31   infrastructure_FunctionAsAService
# 32               infrastructure_Subnet
# 33               infrastructure_Subnet
# 34               infrastructure_Subnet
# 35               infrastructure_Subnet
# 36      infrastructure_InternetGateway
# 37      infrastructure_InternetGateway
# 38                infrastructure_Swarm
# 39        infrastructure_SecurityGroup
# 40        infrastructure_SecurityGroup
# 41            infrastructure_SwarmRole
# 42                infrastructure_Swarm
# 43     concrete_ConcreteInfrastructure
# 44            concrete_RuntimeProvider
# 45            concrete_RuntimeProvider
# 46            concrete_RuntimeProvider
# 47            concrete_RuntimeProvider
# 48            concrete_RuntimeProvider
# 49            concrete_RuntimeProvider
# 50            concrete_RuntimeProvider
# 51             concrete_VirtualMachine
# 52                    concrete_VMImage
# 53             concrete_ContainerImage
# 54                    concrete_Network
# 55                    concrete_Storage
# 56         concrete_FunctionAsAService
# 57             concrete_ComputingGroup
#
#                                                  name  \
# 0                    commons_DOMLElement::annotations
# 1                         commons_Property::reference
# 2                  commons_Configuration::deployments
# 3                       commons_Deployment::component
# 4                            commons_Deployment::node
# 5            application_ApplicationLayer::components
# 6    application_SoftwareComponent::exposedInterfaces
# 7   application_SoftwareComponent::consumedInterfaces
# 8                 application_SaaS::exposedInterfaces
# 9           infrastructure_InfrastructureLayer::nodes
# 10     infrastructure_InfrastructureLayer::generators
# 11       infrastructure_InfrastructureLayer::storages
# 12           infrastructure_InfrastructureLayer::faas
# 13    infrastructure_InfrastructureLayer::credentials
# 14         infrastructure_InfrastructureLayer::groups
# 15  infrastructure_InfrastructureLayer::securityGr...
# 16       infrastructure_InfrastructureLayer::networks
# 17               infrastructure_ComputingNode::ifaces
# 18             infrastructure_ComputingNode::location
# 19          infrastructure_ComputingNode::credentials
# 20                infrastructure_ComputingNode::group
# 21       infrastructure_VirtualMachine::generatedFrom
# 22            infrastructure_Container::generatedFrom
# 23                    infrastructure_Container::hosts
# 24               infrastructure_VMImage::generatedVMs
# 25  infrastructure_ContainerImage::generatedContai...
# 26  infrastructure_AutoScalingGroup::machineDefini...
# 27  infrastructure_AutoScalingGroup::deploymentNet...
# 28     infrastructure_AutoScalingGroup::securityGroup
# 29                                       groupedNodes
# 30                     infrastructure_Storage::ifaces
# 31          infrastructure_FunctionAsAService::ifaces
# 32            infrastructure_Network::connectedIfaces
# 33                       infrastructure_Network::igws
# 34                    infrastructure_Network::subnets
# 35                 infrastructure_Subnet::connectedTo
# 36         infrastructure_NetworkInterface::belongsTo
# 37        infrastructure_NetworkInterface::associated
# 38        infrastructure_ComputingGroup::groupedNodes
# 39                infrastructure_SecurityGroup::rules
# 40               infrastructure_SecurityGroup::ifaces
# 41                    infrastructure_SwarmRole::nodes
# 42                        infrastructure_Swarm::roles
# 43         concrete_ConcreteInfrastructure::providers
# 44                      concrete_RuntimeProvider::vms
# 45                 concrete_RuntimeProvider::vmImages
# 46          concrete_RuntimeProvider::containerImages
# 47                 concrete_RuntimeProvider::networks
# 48                 concrete_RuntimeProvider::storages
# 49                     concrete_RuntimeProvider::faas
# 50                    concrete_RuntimeProvider::group
# 51                      concrete_VirtualMachine::maps
# 52                             concrete_VMImage::maps
# 53                      concrete_ContainerImage::maps
# 54                             concrete_Network::maps
# 55                             concrete_Storage::maps
# 56                  concrete_FunctionAsAService::maps
# 57                      concrete_ComputingGroup::maps
#
#                                        to  \
# 0                        commons_Property
# 1                     commons_DOMLElement
# 2                      commons_Deployment
# 3        application_ApplicationComponent
# 4    infrastructure_InfrastructureElement
# 5        application_ApplicationComponent
# 6           application_SoftwareInterface
# 7           application_SoftwareInterface
# 8           application_SoftwareInterface
# 9            infrastructure_ComputingNode
# 10  infrastructure_ComputingNodeGenerator
# 11                 infrastructure_Storage
# 12      infrastructure_FunctionAsAService
# 13             infrastructure_Credentials
# 14          infrastructure_ComputingGroup
# 15           infrastructure_SecurityGroup
# 16                 infrastructure_Network
# 17        infrastructure_NetworkInterface
# 18                infrastructure_Location
# 19             infrastructure_Credentials
# 20          infrastructure_ComputingGroup
# 21                 infrastructure_VMImage
# 22          infrastructure_ContainerImage
# 23           infrastructure_ComputingNode
# 24          infrastructure_VirtualMachine
# 25               infrastructure_Container
# 26          infrastructure_VirtualMachine
# 27                 infrastructure_Network
# 28           infrastructure_SecurityGroup
# 29           infrastructure_ComputingNode
# 30        infrastructure_NetworkInterface
# 31        infrastructure_NetworkInterface
# 32        infrastructure_NetworkInterface
# 33         infrastructure_InternetGateway
# 34                  infrastructure_Subnet
# 35                 infrastructure_Network
# 36                 infrastructure_Network
# 37           infrastructure_SecurityGroup
# 38           infrastructure_ComputingNode
# 39                    infrastructure_Rule
# 40        infrastructure_NetworkInterface
# 41           infrastructure_ComputingNode
# 42               infrastructure_SwarmRole
# 43               concrete_RuntimeProvider
# 44                concrete_VirtualMachine
# 45                       concrete_VMImage
# 46                concrete_ContainerImage
# 47                       concrete_Network
# 48                       concrete_Storage
# 49            concrete_FunctionAsAService
# 50                concrete_ComputingGroup
# 51          infrastructure_VirtualMachine
# 52                 infrastructure_VMImage
# 53          infrastructure_ContainerImage
# 54                 infrastructure_Network
# 55                 infrastructure_Storage
# 56      infrastructure_FunctionAsAService
# 57          infrastructure_ComputingGroup
#
#                                          inverse
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
# 5                                           None
# 6                                           None
# 7                                           None
# 8                                           None
# 9                                           None
# 10                                          None
# 11                                          None
# 12                                          None
# 13                                          None
# 14                                          None
# 15                                          None
# 16                                          None
# 17                                          None
# 18                                          None
# 19                                          None
# 20   infrastructure_ComputingGroup::groupedNodes
# 21                                          None
# 22                                          None
# 23                                          None
# 24  infrastructure_VirtualMachine::generatedFrom
# 25       infrastructure_Container::generatedFrom
# 26                                          None
# 27                                          None
# 28                                          None
# 29           infrastructure_ComputingNode::group
# 30                                          None
# 31                                          None
# 32    infrastructure_NetworkInterface::belongsTo
# 33                                          None
# 34                                          None
# 35                                          None
# 36                                          None
# 37                                          None
# 38           infrastructure_ComputingNode::group
# 39                                          None
# 40   infrastructure_NetworkInterface::associated
# 41                                          None
# 42                                          None
# 43                                          None
# 44                                          None
# 45                                          None
# 46                                          None
# 47                                          None
# 48                                          None
# 49                                          None
# 50                                          None
# 51                                          None
# 52                                          None
# 53                                          None
# 54                                          None
# 55                                          None
# 56                                          None
# 57                                          None

# %% [markdown]
# ## Z3 Sort Definitions
# Here we define the Sorts of Elements and Associations as Enums (as they are finite), and the relationship between two elements as a Function `AssocRel :: ElemSort, AssocSort, ElemSort -> BoolSort`, which tells us if two items are in a relationship (returns true) or not.

# %%
# Init Z3 solver
s = Solver()

def Iff(a, b):
    return a == b

# %%
ub_elems = { f'elem_ub_{i}' : Elem(
    f'elem_ub_{i}',
    f'Unbound Element #{i}',
    {},
    {},
    unbound=True
    ) 
    for i in range(UB_ELEMS)
}

ELEMS |= ub_elems

# %%
class_sort, classes = EnumSort('Class', list(CLASSES.keys()))
# Add the Ref to each ELEM
for c in classes:
    CLASSES[str(c)].ref = c

elem_sort, elems = EnumSort('Elem', list(ELEMS.keys()))
for elem in elems:
    ELEMS[str(elem)].ref = elem

# Where assoc_sort is an EnumSort of all associations names...
assoc_sort, assocs = EnumSort('Assoc', list(ASSOCS.keys()))
# Add the Ref to each ASSOC
for assoc in assocs:
    ASSOCS[str(assoc)].ref = assoc

attr_sort, attrs = EnumSort('Attr', list(ATTRS.keys()))
# Add the Ref to each ATTR
for attr in attrs:
    ATTRS[str(attr)].ref = attr

# %%
# ElemClass(Elem) -> Class
elem_class_fn = Function('ElemClass', elem_sort, class_sort)

for _, elem in ELEMS.items():
    if not elem.unbound:
        user_friendly_name = f'({elem.name})' if elem.name else ''
        s.assert_and_track(elem_class_fn(elem.ref) == elem.eClass.ref, f'ElemClass {elem.id}{user_friendly_name} {elem.eClass.name}')

# %%
# AssocRel(Elem, Assoc, Elem) -> Bool
assoc_rel = Function('AssocRel', elem_sort, assoc_sort, elem_sort, BoolSort())

assoc_a = Const('assoc_a', assoc_sort)
for (_, e1), (_, e2) in product(ELEMS.items(), ELEMS.items()):
    if (not e1.unbound and not e2.unbound):
        stmt = ForAll(
            [assoc_a],
            Iff(
                assoc_rel(e1.ref, assoc_a, e2.ref),
                Or(
                    *(
                        assoc_a == ASSOCS[e1_assoc_k].ref
                        for e1_assoc_k, e1_assoc_v in e1.associations.items()
                        if e2.id in e1_assoc_v
                    )
                )
            )
        )
        s.assert_and_track(stmt, f'AssocRel {e1.id} {e2.id}')

# %%
# WORKING - 4 Jan 2023 17:30
# # AttrRel(Elem, Attr, Value) -> Bool
# attr_int_rel = Function('AttrIntRel', elem_sort, attr_sort, IntSort(), BoolSort())
# # ...do the others
# attr_a = Const('attr_a', attr_sort)
# attr_value_b = Const('attr_value_b', IntSort())
# for _, elem in ELEMS.items():
#     if elem.eClass:
#         eClassAttrs = elem.eClass.attributes
#         print(f'{elem.id} {elem.name}')
#         for k, v in eClassAttrs.items():
#             if v['type'] == 'Integer':
#                 print('\t', k)
#         stmt = ForAll(
#             [attr_a],
#             Iff(
#                 attr_int_rel(elem.ref, attr_a, attr_value_b),
#                 Or(
#                     *(
#                         attr_a == ATTRS[attr_name].ref
#                         for attr_name, attr_value in eClassAttrs.items()
#                         if attr_value['type'] == 'Integer'
#                     )
#                 )
#             )
#         )
#         s.assert_and_track(stmt, f'AttrIntRel {elem.id} Int')

# TEST - 4 Jan 2023 17:30 - WORKS
# AttrRel(Elem, Attr) -> Bool
# True if Elem has Attr relationship
# attr_int_exist_rel = Function('AttrIntExistRel', elem_sort, attr_sort, BoolSort())
# # ...do the others
# attr_a = Const('attr_a', attr_sort)
# for _, elem in ELEMS.items():
#     if elem.eClass:
#         eClassAttrs = elem.eClass.attributes
#         print(f'{elem.id} {elem.name}')
#         for k, v in eClassAttrs.items():
#             type = v['type']
#             print(f'\t{k} ({type})')
#         stmt = ForAll(
#             [attr_a],
#             Iff(
#                 attr_int_exist_rel(elem.ref, attr_a),
#                 Or(
#                     *(
#                         attr_a == ATTRS[attr_name].ref
#                         for attr_name, attr_value in eClassAttrs.items()
#                         if attr_value['type'] == 'Integer'
#                     )
#                 )
#             )
#         )
#         s.assert_and_track(stmt, f'AttrIntExistRel {elem.id}')

attr_int_exist_rel = Function('AttrIntExistRel', elem_sort, attr_sort, BoolSort())
elem_a = Const('elem_a', elem_sort)
attr_a = Const('attr_a', attr_sort)
for class_k, class_v in CLASSES.items():
    s.assert_and_track((
        ForAll(
            [elem_a],
            Implies(
                elem_class_fn(elem_a) == class_v.ref,
                ForAll(
                    [attr_a],
                    Iff(
                        attr_int_exist_rel(elem_a, attr_a),
                        Or(
                            *(
                                attr_a == ATTRS[i].ref
                                for i in class_v.attributes.keys()
                                if ATTRS[i].type == 'Integer'
                            )
                        )
                    )    
                )
            )
        )
    ), f'AttrIntExistRel {class_k}')

# %%
assert(s.check() == sat)

# %% [markdown]
# Since we're done with the setup, we need to be sure that the base model is satisfiable!
#
# Right now we're not checking any requirement. We're just telling the solver which are the valid relationships between stuff.

# %%
vm, iface = Consts("vm iface", elem_sort)

req_vm_iface = ForAll(
    [vm],
    Implies(
        elem_class_fn(vm) == CLASSES["infrastructure_VirtualMachine"].ref,
        Exists(
            [iface],
            And(
                assoc_rel(vm, ASSOCS["infrastructure_ComputingNode::ifaces"].ref, iface)
            )
        )
    )
)
s.assert_and_track(req_vm_iface, "vm_iface")

# %%
vm = Const("vm", elem_sort)
CpuCount = Int("cpucount")

# req_vm_cpucount = ForAll(
#     [vm],
#     Implies(
#         elem_class_fn(vm) == CLASSES["infrastructure_VirtualMachine"].ref,
#         Exists(
#             [CpuCount],
#             And(
#                 attr_int_rel(vm, ATTRS["infrastructure_ComputingNode::cpu_count"].ref, CpuCount),
#                 CpuCount == 5
#             )
#         )
#     )
# )
# s.assert_and_track(req_vm_cpucount, "vm_cpucount")

req_vm_cpucount = ForAll(
    [vm],
    Implies(
        elem_class_fn(vm) == CLASSES["infrastructure_VirtualMachine"].ref,
        
        attr_int_exist_rel(vm, ATTRS["infrastructure_ComputingNode::cpu_count"].ref)
    )
)
s.assert_and_track(req_vm_cpucount, "vm_cpucount")

# %% [markdown]
# In `req_vm_cpucount` when using
# ```python
# attr_int_exist_rel(vm, ATTRS["infrastructure_ComputingNode::cpu_count"].ref)
# ```
# it works (produces *sat*) since `cpu_count` is indeed a property of VM.
#
# If we use another attr. key instead, such as `infrastructure_KeyPair::keyfile`,
# we get *unsat* as a result, which is consistent, since `keyfile` doesn't belong to the
# properties of a VM.

# %%
isSat = s.check()
assert(isSat)
print(isSat)
# Out:
# sat

# %% [markdown]
# ### Tests

# %%
# TEST: VirtualMachine must have only its own attribute relationship, and not others.
# VirtualMachine DOES NOT have Attribute infrastructure_Rule::cidr
# so we're expecting it to be unsatisfiable
s.push()
s.add(
    ForAll(
        [vm],
        Implies(
            elem_class_fn(vm) == CLASSES["infrastructure_VirtualMachine"].ref,
            attr_int_exist_rel(vm, ATTRS["infrastructure_Rule::cidr"].ref)
        )
    )
)
# If this fails, it means that you are assigning attribute relationship wrong!
assert s.check() == unsat
s.pop()

# %%
# Same test, for another component, but this time it MUST have its own attribute.
s.push()
s.add(
    ForAll(
        [vm],
        Implies(
            elem_class_fn(vm) == CLASSES["infrastructure_Rule"].ref,
            attr_int_exist_rel(vm, ATTRS["infrastructure_Rule::fromPort"].ref)
        )
    )
)
# If this fails, it means that you are assigning attribute relationship wrong!
assert s.check() == sat
s.pop()

# %%
s.check()
model = s.model()

# %%
model_df = pd.DataFrame([str(x).split(' ') for x in list(model)])

model_df.sort_values(by=0)
# Out:
#                    0                                        1  \
# 0           AssocRel                     elem_139682453244048
# 528         AssocRel                     elem_139682453246416
# 529         AssocRel                     elem_139682454976784
# 530         AssocRel                     elem_139682468739152
# 532         AssocRel                     elem_139682453252752
# 534         AssocRel                     elem_139682455132112
# 535         AssocRel                     elem_139682453248272
# 536         AssocRel                     elem_139682453248016
# 537         AssocRel                     elem_139682454978384
# 538         AssocRel                     elem_139682467223760
# 527         AssocRel                     elem_139682453253200
# 539         AssocRel                     elem_139682468739152
# 541         AssocRel                     elem_139682454968848
# 542         AssocRel                     elem_139682453248272
# 543         AssocRel                     elem_139682454976784
# 544         AssocRel                     elem_139682454978384
# 545         AssocRel                     elem_139682454978384
# 546         AssocRel                     elem_139682454978448
# 547         AssocRel                     elem_139682465716176
# 548         AssocRel                     elem_139682453254480
# 549         AssocRel                     elem_139682467223760
# 540         AssocRel                     elem_139682453247120
# 550         AssocRel                     elem_139682453252752
# 526         AssocRel                     elem_139682453244048
# 522         AssocRel                     elem_139682467402256
# 501         AssocRel                     elem_139682467402256
# 502         AssocRel                     elem_139682468739152
# 503         AssocRel                     elem_139682453247120
# 504         AssocRel                     elem_139682467580048
# 505         AssocRel                     elem_139682453246416
# 506         AssocRel                     elem_139682454976784
# 507         AssocRel                     elem_139682467402256
# 508         AssocRel                     elem_139682454968848
# 509         AssocRel                     elem_139682453247120
# 523         AssocRel                     elem_139682454964944
# 511         AssocRel                     elem_139682454964944
# 513         AssocRel                     elem_139682465984400
# 514         AssocRel                     elem_139682467588752
# 515         AssocRel                     elem_139682465716176
# 516         AssocRel                     elem_139682453254480
# 517         AssocRel                     elem_139682465984400
# 518         AssocRel                     elem_139682453248272
# 519         AssocRel                     elem_139682453254480
# 520         AssocRel                     elem_139682467580048
# 521         AssocRel                     elem_139682454978448
# 512         AssocRel                     elem_139682453246288
# 500         AssocRel                     elem_139682454978448
# 552         AssocRel                     elem_139682454978448
# 554         AssocRel                     elem_139682467580048
# 243                elem_139682453252752
# 244                elem_139682454968848
# 245                elem_139682453247120
# 246                elem_139682453252816
# 373                elem_139682467399824
# 247                elem_139682467408848
# 248                elem_139682453246288
# 241                elem_139682453246288
# 249                elem_139682455130192
# 232                elem_139682453246288
# 230                elem_139682467399824
# 216                elem_139682467402256
# 217                elem_139682467402256
# 383                elem_139682455132112
# 218                elem_139682467223760
# 219                elem_139682465716176
# 220                elem_139682465984400
# 221                elem_139682454976784
# 382                elem_139682453246288
# 231                elem_139682454968848
# 222                elem_139682453252752
# 224                elem_139682453254480
# 225                elem_139682453247120
# 226                elem_139682453244048
# 379                elem_139682454976784
# 378                elem_139682453246288
# 227                elem_139682468739152
# 377                elem_139682453248016
# 229                elem_139682467402256
# 380                elem_139682467408848
# 364                elem_139682453248016
# 345                elem_139682467066960
# 263                elem_139682467580048
# 269                elem_139682454978448
# 268                elem_139682453247120
# 267                elem_139682454968848
# 367                elem_139682453248272
# 366                elem_139682467580048
# 265                elem_139682453252752
# 275                elem_139682467408848
# 264                elem_139682467223760
# 370                elem_139682453248016
# 276                elem_139682454968848
# 270                elem_139682465984400
# 262                elem_139682453246416
# 368                elem_139682453252752
# 260                elem_139682468739152
# 252                elem_139682467588752
# 253                elem_139682453248016
# 254                elem_139682453248272
# 255                elem_139682454968848
# 256                elem_139682467223760
# 261                elem_139682453252816
# 257                elem_139682453246416
# 258                elem_139682453252816
# 277                elem_139682453247120
# 259                elem_139682453246416
# 748                                None
# 365                                None
# 415                                None
# 411                                None
# 31                                 None
# 14                                 None
# 21                                 None
# 36                                 None
# 369                                None
# 42                                 None
# 420                                None
# 371                                None
# 791                                None
# 16                                 None
# 793                                None
# 400                                None
# 406                                None
# 413                                None
# 578                                None
# 61                                 None
# 284                                None
# 132                                None
# 662                                None
# 659                                None
# 59                                 None
# 273                                None
# 271                                None
# 266                                None
# 154                                None
# 524                                None
# 640                                None
# 533                                None
# 630                                None
# 251                                None
# 551                                None
# 228                                None
# 594                                None
# 223                                None
# 211                                None
# 290                                None
# 492                                None
# 811                                None
# 490                                None
# 729                                None
# 86                                 None
# 93                                 None
# 96                                 None
# 97                                 None
# 707                                None
# 473                                None
# 684                                None
# 327                                None
# 381                  commons_Deployment
# 391     concrete_ConcreteInfrastructure
# 56               infrastructure_KeyPair
# 734        infrastructure_SecurityGroup
# 329  infrastructure_InfrastructureLayer
# 200                 infrastructure_Rule
# 809                                None
# 394                   commons_SProperty
# 731                   commons_SProperty
# 376              infrastructure_Network
# 190              infrastructure_VMImage
# 177                   commons_SProperty
# 571                    concrete_Network
# 525                 infrastructure_Rule
# 531     infrastructure_NetworkInterface
# 418     infrastructure_AutoScalingGroup
# 372       application_SoftwareComponent
# 720                   commons_SProperty
# 404             concrete_VirtualMachine
# 151                 infrastructure_Rule
# 272                 infrastructure_Rule
# 764            concrete_RuntimeProvider
# 510       infrastructure_VirtualMachine
# 279                   commons_SProperty
# 471               commons_Configuration
# 414                    concrete_VMImage
# 429                   commons_SProperty
# 274        application_ApplicationLayer
# 67                                 None
# 85                                 None
